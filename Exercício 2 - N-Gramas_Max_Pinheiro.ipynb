# %% [markdown]
# #Aluno: Max Pinheiro matrícula: 1831143046

# %% [markdown]
# # Exercício 2 - N-Gramas

# %% [markdown]
# Neste exercício, vamos construir um modelo linguístico baseados em n-gramas. Para criarmos esse modelo, usaremos a frequência relativa para calcular a probabilidade de uma palavra aparecer dado uma sequência de palavras. Com o modelo, vamos gerar um texto baseado no corpus de treinamento.

# %%
from nltk.corpus import machado
from nltk.util import bigrams, trigrams, ngrams
from collections import Counter
import pandas as pd
import random

# %% [markdown]
# Vamos utilizar um corpus em português para gerar nosso modelo. Vamos carregar, a partir do corpus Machado do NLTK, o texto Memórias Póstumas de Brás Cubas. Vamos carregar uma lista de sentenças tokenizadas.
#
# corpus instalado via conda: python -m nltk downloader.machado

# %%
corpus = machado.sents('romance/marm05.txt')
corpus[:100]
# Out:
# [['Romance', ',', 'Memórias', 'Póstumas', 'de', 'Brás', 'Cubas', ',', '1880'], ['Memórias', 'Póstumas', 'de', 'Brás', 'Cubas'], ...]

# %%
type(corpus)
# Out:
# nltk.corpus.reader.util.StreamBackedCorpusView

# %% [markdown]
# Para gerar o modelo corretamente, precisamos demarcar onde a sentença começa e onde termina. Vamos adicionar tokens de início e fim de sentença. Vamos criar um modelo de trigrama, assim, o primeiro trigrama precisa desmarcar a primeira palavra da sentença. Por isso, adicionamos dois tokens de início em cada sentença e um de fim no final. Aqui também convertemos a nossa lista de sentenças em uma lista de palavras.

# %%
words = []
for sent in corpus:
    sent.insert(0, '<s>')#insere token no início da sentença
    sent.insert(0, '<s>')
    sent.append('</s>')
    words.extend(sent)

# %%
words[0:20]
# Out:
# ['<s>',
#  '<s>',
#  'Romance',
#  ',',
#  'Memórias',
#  'Póstumas',
#  'de',
#  'Brás',
#  'Cubas',
#  ',',
#  '1880',
#  '</s>',
#  '<s>',
#  '<s>',
#  'Memórias',
#  'Póstumas',
#  'de',
#  'Brás',
#  'Cubas',
#  '</s>']

# %%
type(words)
# Out:
# list

# %%
words[0]
# Out:
# '<s>'

# %% [markdown]
# Vamos agora gerar as trigramas e bigramas necessárias para o modelo. Para isso, usamos a função bigrams e trigrams do pacote NLTK que facilita nosso trabalho. A função funciona a partir de listas de palavras previamente segmentadas.

# %%
words_bigram = bigrams(words)
words_trigram = trigrams(words)

# %%
words_bigram
# Out:
# <generator object bigrams at 0x000002B66ECBD048>

# %%
print(words_bigram)
# Out:
# <generator object bigrams at 0x000002B66ECBD048>

# %%
type(words_bigram)
# Out:
# generator

# %% [markdown]
# Vamos contar os bigramas, para isso vamos usar o Counter.

# %%
count_bigram = Counter(words_bigram)
count_bigram
# Out:
# Counter({('<s>', '<s>'): 3822,
#          ('<s>', 'Romance'): 1,
#          ('Romance', ','): 1,
#          (',', 'Memórias'): 1,
#          ('Memórias', 'Póstumas'): 5,
#          ('Póstumas', 'de'): 4,
#          ('de', 'Brás'): 6,
#          ('Brás', 'Cubas'): 29,
#          ('Cubas', ','): 16,
#          (',', '1880'): 1,
#          ('1880', '</s>'): 1,
#          ('</s>', '<s>'): 3821,
#          ('<s>', 'Memórias'): 1,
#          ('Cubas', '</s>'): 1,
#          ('<s>', 'Texto'): 1,
#          ('Texto', '-'): 1,
#          ('-', 'fonte'): 1,
#          ('fonte', ':'): 1,
#          (':', 'Obra'): 1,
#          ('Obra', 'Completa'): 1,
#          ('Completa', ','): 1,
#          (',', 'Machado'): 1,
#          ('Machado', 'de'): 2,
#          ('de', 'Assis'): 2,
#          ('Assis', ','): 1,
#          (',', 'Rio'): 1,
#          ('Rio', 'de'): 8,
#          ('de', 'Janeiro'): 8,
#          ('Janeiro', ':'): 1,
#          (':', 'Editora'): 1,
#          ('Editora', 'Nova'): 1,
#          ('Nova', 'Aguilar'): 1,
#          ('Aguilar', ','): 1,
#          (',', '1994'): 1,
#          ('1994', '.'): 1,
#          ('.', '</s>'): 2813,
#          ('<s>', 'Publicado'): 1,
#          ('Publicado', 'originalmente'): 1,
#          ('originalmente', 'em'): 1,
#          ('em', 'folhetins'): 1,
#          ('folhetins', ','): 1,
#          (',', 'a'): 273,
#          ('a', 'partir'): 1,
#          ('partir', 'de'): 1,
#          ('de', 'março'): 2,
#          ('março', 'de'): 1,
#          ('de', '1880'): 2,
#          ('1880', ','): 1,
#          (',', 'na'): 37,
#          ('na', 'Revista'): 2,
#          ('Revista', 'Brasileira'): 2,
#          ('Brasileira', '.'): 1,
#          ('<s>', 'Ao'): 33,
#          ('Ao', 'verme'): 1,
#          ('verme', 'que'): 1,
#          ('que', 'primeiro'): 2,
#          ('primeiro', 'roeu'): 1,
#          ('roeu', 'as'): 1,
#          ('as', 'frias'): 1,
#          ('frias', 'carnes'): 1,
#          ('carnes', 'do'): 1,
#          ('do', 'meu'): 29,
#          ('meu', 'cadáver'): 1,
#          ('cadáver', '</s>'): 1,
#          ('<s>', 'dedico'): 1,
#          ('dedico', 'como'): 1,
#          ('como', 'saudosa'): 1,
#          ('saudosa', 'lembrança'): 1,
#          ('lembrança', '</s>'): 1,
#          ('<s>', 'estas'): 1,
#          ('estas', 'Memórias'): 1,
#          ('Póstumas', '</s>'): 1,
#          ('<s>', 'Prólogo'): 1,
#          ('Prólogo', 'da'): 1,
#          ('da', 'terceira'): 1,
#          ('terceira', 'edição'): 2,
#          ('edição', '</s>'): 1,
#          ('<s>', 'A'): 125,
#          ('A', 'primeira'): 2,
#          ('primeira', 'edição'): 2,
#          ('edição', 'destas'): 1,
#          ('destas', 'Memórias'): 2,
#          ('Cubas', 'foi'): 1,
#          ('foi', 'feita'): 1,
#          ('feita', 'aos'): 1,
#          ('aos', 'pedaços'): 1,
#          ('pedaços', 'na'): 1,
#          ('Brasileira', ','): 1,
#          (',', 'pelos'): 2,
#          ('pelos', 'anos'): 1,
#          ('anos', 'de'): 3,
#          ('1880', '.'): 1,
#          ('<s>', 'Postas'): 1,
#          ('Postas', 'mais'): 1,
#          ('mais', 'tarde'): 8,
#          ('tarde', 'em'): 1,
#          ('em', 'livro'): 1,
#          ('livro', ','): 11,
#          (',', 'corrigi'): 2,
#          ('corrigi', 'o'): 1,
#          ('o', 'texto'): 1,
#          ('texto', 'em'): 1,
#          ('em', 'vários'): 1,
#          ('vários', 'lugares'): 1,
#          ('lugares', '.'): 2,
#          ('<s>', 'Agora'): 18,
#          ('Agora', 'que'): 1,
#          ('que', 'tive'): 2,
#          ('tive', 'de'): 1,
#          ('de', 'o'): 12,
#          ('o', 'rever'): 1,
#          ('rever', 'para'): 1,
#          ('para', 'a'): 42,
#          ('a', 'terceira'): 4,
#          ('edição', ','): 3,
#          (',', 'emendei'): 1,
#          ('emendei', 'ainda'): 1,
#          ('ainda', 'alguma'): 1,
#          ('alguma', 'coisa'): 44,
#          ('coisa', 'e'): 2,
#          ('e', 'suprimi'): 1,
#          ('suprimi', 'duas'): 1,
#          ('duas', 'ou'): 5,
#          ('ou', 'três'): 7,
#          ('três', 'dúzias'): 1,
#          ('dúzias', 'de'): 2,
#          ('de', 'linhas'): 1,
#          ('linhas', '.'): 1,
#          ('<s>', 'Assim'): 12,
#          ('Assim', 'composta'): 1,
#          ('composta', ','): 1,
#          (',', 'sai'): 1,
#          ('sai', 'novamente'): 1,
#          ('novamente', 'à'): 1,
#          ('à', 'luz'): 5,
#          ('luz', 'esta'): 1,
#          ('esta', 'obra'): 1,
#          ('obra', 'que'): 1,
#          ('que', 'alguma'): 1,
#          ('alguma', 'benevolência'): 1,
#          ('benevolência', 'parece'): 1,
#          ('parece', 'ter'): 1,
#          ('ter', 'encontrado'): 1,
#          ('encontrado', 'no'): 1,
#          ('no', 'público'): 1,
#          ('público', '.'): 2,
#          ('<s>', 'Capistrano'): 1,
#          ('Capistrano', 'de'): 1,
#          ('de', 'Abreu'): 1,
#          ('Abreu', ','): 1,
#          (',', 'noticiando'): 1,
#          ('noticiando', 'a'): 1,
#          ('a', 'publicação'): 3,
#          ('publicação', 'do'): 1,
#          ('do', 'livro'): 8,
#          (',', 'perguntava'): 3,
#          ('perguntava', ':'): 1,
#          (':', '\x93'): 9,
#          ('\x93', 'As'): 1,
#          ('As', 'Memórias'): 1,
#          ('Cubas', 'são'): 1,
#          ('são', 'um'): 2,
#          ('um', 'romance'): 1,
#          ('romance', '?\x94'): 1,
#          ('?\x94', 'Macedo'): 1,
#          ('Macedo', 'Soares'): 1,
#          ('Soares', ','): 1,
#          (',', 'em'): 62,
#          ('em', 'carta'): 1,
#          ('carta', 'que'): 1,
#          ('que', 'me'): 121,
#          ('me', 'escreveu'): 1,
#          ('escreveu', 'por'): 1,
#          ('por', 'esse'): 8,
#          ('esse', 'tempo'): 11,
#          ('tempo', ','): 36,
#          (',', 'recordava'): 1,
#          ('recordava', 'amigamente'): 1,
#          ('amigamente', 'as'): 1,
#          ('as', 'Viagens'): 1,
#          ('Viagens', 'na'): 1,
#          ('na', 'minha'): 17,
#          ('minha', 'terra'): 1,
#          ('terra', '.'): 1,
#          ('Ao', 'primeiro'): 1,
#          ('primeiro', 'respondia'): 1,
#          ('respondia', 'já'): 1,
#          ('já', 'o'): 2,
#          ('o', 'defunto'): 2,
#          ('defunto', 'Brás'): 1,
#          ('Cubas', '('): 1,
#          ('(', 'como'): 2,
#          ('como', 'o'): 23,
#          ('o', 'leitor'): 19,
#          ('leitor', 'viu'): 1,
#          ('viu', 'e'): 1,
#          ('e', 'verá'): 2,
#          ('verá', 'no'): 1,
#          ('no', 'prólogo'): 1,
#          ('prólogo', 'dele'): 1,
#          ('dele', 'que'): 1,
#          ('que', 'vai'): 3,
#          ('vai', 'adiante'): 1,
#          ('adiante', ')'): 1,
#          (')', 'que'): 4,
#          ('que', 'sim'): 11,
#          ('sim', 'e'): 1,
#          ('e', 'que'): 32,
#          ('que', 'não'): 143,
#          ('não', ','): 13,
#          (',', 'que'): 446,
#          ('que', 'era'): 85,
#          ('era', 'romance'): 1,
#          ('romance', 'para'): 1,
#          ('para', 'uns'): 1,
#          ('uns', 'e'): 1,
#          ('e', 'não'): 73,
#          ('não', 'o'): 6,
#          ('o', 'era'): 3,
#          ('era', 'para'): 3,
#          ('para', 'outros'): 1,
#          ('outros', '.'): 10,
#          ('<s>', 'Quanto'): 16,
#          ('Quanto', 'ao'): 4,
#          ('ao', 'segundo'): 1,
#          ('segundo', ','): 2,
#          (',', 'assim'): 8,
#          ('assim', 'se'): 1,
#          ('se', 'explicou'): 1,
#          ('explicou', 'o'): 1,
#          ('o', 'finado'): 1,
#          ('finado', ':'): 1,
#          ('\x93', 'Trata'): 1,
#          ('Trata', '-'): 3,
#          ('-', 'se'): 287,
#          ('se', 'de'): 13,
#          ('de', 'uma'): 110,
#          ('uma', 'obra'): 3,
#          ('obra', 'difusa'): 2,
#          ('difusa', ','): 2,
#          ('na', 'qual'): 3,
#          ('qual', 'eu'): 3,
#          ('eu', ','): 38,
#          (',', 'Brás'): 7,
#          (',', 'se'): 105,
#          ('se', 'adotei'): 2,
#          ('adotei', 'a'): 2,
#          ('a', 'forma'): 4,
#          ('forma', 'livre'): 2,
#          ('livre', 'de'): 3,
#          ('de', 'um'): 156,
#          ('um', 'Sterne'): 2,
#          ('Sterne', 'ou'): 1,
#          ('ou', 'de'): 11,
#          ('um', 'Xavier'): 2,
#          ('Xavier', 'de'): 3,
#          ('de', 'Maistre'): 3,
#          ('Maistre', ','): 2,
#          (',', 'não'): 176,
#          ('não', 'sei'): 37,
#          ('sei', 'se'): 23,
#          ('se', 'lhe'): 11,
#          ('lhe', 'meti'): 2,
#          ('meti', 'algumas'): 2,
#          ('algumas', 'rabugens'): 2,
#          ('rabugens', 'de'): 3,
#          ('de', 'pessimismo'): 3,
#          ('pessimismo', '.\x94'): 1,
#          ('.\x94', 'Toda'): 1,
#          ('Toda', 'essa'): 1,
#          ('essa', 'gente'): 1,
#          ('gente', 'viajou'): 1,
#          ('viajou', ':'): 1,
#          (':', 'Xavier'): 1,
#          ('Maistre', 'à'): 1,
#          ('à', 'roda'): 5,
#          ('roda', 'do'): 2,
#          ('do', 'quarto'): 3,
#          ('quarto', ','): 2,
#          (',', 'Garret'): 1,
#          ('Garret', 'na'): 1,
#          ('na', 'terra'): 2,
#          ('terra', 'dele'): 1,
#          ('dele', ','): 15,
#          (',', 'Sterne'): 1,
#          ('Sterne', 'na'): 1,
#          ('terra', 'dos'): 1,
#          ('dos', 'outros'): 12,
#          ('<s>', 'De'): 31,
#          ('De', 'Brás'): 1,
#          ('Cubas', 'se'): 1,
#          ('se', 'pode'): 5,
#          ('pode', 'dizer'): 2,
#          ('dizer', 'que'): 20,
#          ('que', 'viajou'): 1,
#          ('viajou', 'à'): 1,
#          ('roda', 'da'): 1,
#          ('da', 'vida'): 34,
#          ('vida', '.'): 12,
#          ('<s>', 'O'): 110,
#          ('O', 'que'): 15,
#          ('que', 'faz'): 7,
#          ('faz', 'do'): 1,
#          ('meu', 'Brás'): 1,
#          ('Cubas', 'um'): 1,
#          ('um', 'autor'): 2,
#          ('autor', 'particular'): 1,
#          ('particular', 'é'): 1,
#          ('é', 'o'): 36,
#          ('o', 'que'): 104,
#          ('que', 'ele'): 54,
#          ('ele', 'chama'): 1,
#          ('chama', '\x93'): 1,
#          ('\x93', 'rabugens'): 1,
#          ('pessimismo', '\x94.'): 1,
#          ('\x94.', '</s>'): 12,
#          ('<s>', 'Há'): 9,
#          ('Há', 'na'): 1,
#          ('na', 'alma'): 1,
#          ('alma', 'deste'): 1,
#          ('deste', 'livro'): 7,
#          (',', 'por'): 61,
#          ('por', 'mais'): 3,
#          ('mais', 'risonho'): 1,
#          ('risonho', 'que'): 1,
#          ('que', 'pareça'): 1,
#          ('pareça', ','): 1,
#          (',', 'um'): 114,
#          ('um', 'sentimento'): 5,
#          ('sentimento', 'amargo'): 1,
#          ('amargo', 'e'): 2,
#          ('e', 'áspero'): 1,
#          ('áspero', ','): 2,
#          ('que', 'está'): 4,
#          ('está', 'longe'): 1,
#          ('longe', 'de'): 7,
#          ('de', 'vir'): 5,
#          ('vir', 'de'): 1,
#          ('de', 'seus'): 5,
#          ('seus', 'modelos'): 1,
#          ('modelos', '.'): 1,
#          ('<s>', 'É'): 17,
#          ('É', 'taça'): 1,
#          ('taça', 'que'): 1,
#          ('que', 'pode'): 2,
#          ('pode', 'ter'): 1,
#          ('ter', 'lavores'): 1,
#          ('lavores', 'de'): 1,
#          ('de', 'igual'): 2,
#          ('igual', 'escola'): 1,
#          ('escola', ','): 6,
#          (',', 'mas'): 159,
#          ('mas', 'leva'): 1,
#          ('leva', 'outro'): 1,
#          ('outro', 'vinho'): 1,
#          ('vinho', '.'): 2,
#          ('<s>', 'Não'): 185,
#          ('Não', 'digo'): 10,
#          ('digo', 'mais'): 4,
#          ('mais', 'para'): 2,
#          ('para', 'não'): 6,
#          ('não', 'entrar'): 1,
#          ('entrar', 'na'): 3,
#          ('na', 'crítica'): 1,
#          ('crítica', 'de'): 1,
#          ('um', 'defunto'): 4,
#          ('defunto', ','): 3,
#          ('que', 'se'): 63,
#          ('se', 'pintou'): 1,
#          ('pintou', 'a'): 1,
#          ('a', 'si'): 12,
#          ('si', 'e'): 2,
#          ('e', 'a'): 103,
#          ('a', 'outros'): 2,
#          ('outros', ','): 12,
#          (',', 'conforme'): 2,
#          ('conforme', 'lhe'): 1,
#          ('lhe', 'pareceu'): 1,
#          ('pareceu', 'melhor'): 1,
#          ('melhor', 'e'): 1,
#          ('e', 'mais'): 11,
#          ('mais', 'certo'): 1,
#          ('certo', '.'): 2,
#          ('<s>', 'Machado'): 1,
#          ('Assis', '.'): 1,
#          ('<s>', 'AO'): 1,
#          ('AO', 'LEITOR'): 1,
#          ('LEITOR', '</s>'): 1,
#          ('<s>', 'Que'): 39,
#          ('Que', 'Stendhal'): 1,
#          ('Stendhal', 'confessasse'): 1,
#          ('confessasse', 'haver'): 1,
#          ('haver', 'escrito'): 1,
#          ('escrito', 'um'): 1,
#          ('um', 'de'): 3,
#          ('seus', 'livros'): 2,
#          ('livros', 'para'): 1,
#          ('para', 'cem'): 1,
#          ('cem', 'leitores'): 2,
#          ('leitores', ','): 2,
#          (',', 'coisa'): 7,
#          ('coisa', 'é'): 7,
#          ('é', 'que'): 89,
#          ('que', 'admira'): 1,
#          ('admira', 'e'): 1,
#          ('e', 'consterna'): 1,
#          ('consterna', '.'): 1,
#          ('não', 'admira'): 2,
#          ('admira', ','): 1,
#          (',', 'nem'): 82,
#          ('nem', 'provavelmente'): 1,
#          ('provavelmente', 'consternará'): 1,
#          ('consternará', 'é'): 1,
#          ('é', 'se'): 2,
#          ('se', 'este'): 2,
#          ('este', 'outro'): 3,
#          ('outro', 'livro'): 1,
#          ('livro', 'não'): 1,
#          ('não', 'tiver'): 1,
#          ('tiver', 'os'): 1,
#          ('os', 'cem'): 1,
#          ('leitores', 'de'): 1,
#          ('de', 'Stendhal'): 2,
#          ('Stendhal', ','): 2,
#          ('nem', 'cinqüenta'): 1,
#          ('cinqüenta', ','): 2,
#          ('nem', 'vinte'): 1,
#          ('vinte', 'e'): 4,
#          ('e', ','): 49,
#          (',', 'quando'): 55,
#          ('quando', 'muito'): 3,
#          ('muito', ','): 25,
#          (',', 'dez'): 1,
#          ('dez', '.'): 1,
#          ('<s>', 'Dez'): 1,
#          ('Dez', '?'): 1,
#          ('?', '</s>'): 262,
#          ('<s>', 'Talvez'): 30,
#          ('Talvez', 'cinco'): 2,
#          ('cinco', '.'): 1,
#          ('<s>', 'Trata'): 3,
#          ('se', ','): 36,
#          ('na', 'verdade'): 4,
#          ('verdade', ','): 26,
#          (',', 'de'): 97,
#          ('Sterne', ','): 1,
#          (',', 'ou'): 67,
#          ('pessimismo', '.'): 1,
#          ('<s>', 'Pode'): 1,
#          ('Pode', 'ser'): 3,
#          ('ser', '.'): 4,
#          ('<s>', 'Obra'): 1,
#          ('Obra', 'de'): 1,
#          ('de', 'finado'): 1,
#          ('finado', '.'): 1,
#          ('<s>', 'Escrevi'): 2,
#          ('Escrevi', '-'): 1,
#          ('-', 'a'): 100,
#          ('a', 'com'): 10,
#          ('com', 'a'): 87,
#          ('a', 'pena'): 11,
#          ('pena', 'da'): 1,
#          ('da', 'galhofa'): 1,
#          ('galhofa', 'e'): 1,
#          ('a', 'tinta'): 1,
#          ('tinta', 'da'): 1,
#          ('da', 'melancolia'): 3,
#          ('melancolia', ','): 2,
#          (',', 'e'): 727,
#          ('não', 'é'): 45,
#          ('é', 'difícil'): 1,
#          ('difícil', 'antever'): 1,
#          ('antever', 'o'): 1,
#          ('que', 'poderá'): 1,
#          ('poderá', 'sair'): 1,
#          ('sair', 'desse'): 1,
#          ('desse', 'conúbio'): 1,
#          ('conúbio', '.'): 1,
#          ('<s>', 'Acresce'): 3,
#          ('Acresce', 'que'): 3,
#          ('que', 'a'): 132,
#          ('a', 'gente'): 10,
#          ('gente', 'grave'): 1,
#          ('grave', 'achará'): 1,
#          ('achará', 'no'): 1,
#          ('no', 'livro'): 2,
#          ('livro', 'umas'): 1,
#          ('umas', 'aparências'): 1,
#          ('aparências', 'de'): 1,
#          ('de', 'puro'): 1,
#          ('puro', 'romance'): 1,
#          ('romance', ','): 2,
#          (',', 'ao'): 75,
#          ('ao', 'passo'): 10,
#          ('passo', 'que'): 12,
#          ('gente', 'frívola'): 1,
#          ('frívola', 'não'): 1,
#          ('não', 'achará'): 1,
#          ('achará', 'nele'): 1,
#          ('nele', 'o'): 2,
#          ('o', 'seu'): 28,
#          ('seu', 'romance'): 1,
#          ('romance', 'usual'): 1,
#          ('usual', ';'): 1,
#          (';', 'ei'): 2,
#          ('ei', '-'): 4,
#          ('-', 'lo'): 77,
#          ('lo', 'aí'): 1,
#          ('aí', 'fica'): 3,
#          ('fica', 'privado'): 1,
#          ('privado', 'da'): 1,
#          ('da', 'estima'): 1,
#          ('estima', 'dos'): 1,
#          ('dos', 'graves'): 1,
#          ('graves', 'e'): 1,
#          ('e', 'do'): 24,
#          ('do', 'amor'): 6,
#          ('amor', 'dos'): 1,
#          ('dos', 'frívolos'): 1,
#          ('frívolos', ','): 1,
#          ('que', 'são'): 2,
#          ('são', 'as'): 3,
#          ('as', 'duas'): 5,
#          ('duas', 'colunas'): 1,
#          ('colunas', 'máximas'): 1,
#          ('máximas', 'da'): 1,
#          ('da', 'opinião'): 7,
#          ('opinião', '.'): 2,
#          ('<s>', 'Mas'): 68,
#          ('Mas', 'eu'): 10,
#          ('eu', 'ainda'): 2,
#          ('ainda', 'espero'): 1,
#          ('espero', 'angariar'): 1,
#          ('angariar', 'as'): 1,
#          ('as', 'simpatias'): 1,
#          ('simpatias', 'da'): 1,
#          ('opinião', ','): 10,
#          ('e', 'o'): 78,
#          ('o', 'primeiro'): 14,
#          ('primeiro', 'remédio'): 1,
#          ('remédio', 'é'): 1,
#          ('é', 'fugir'): 1,
#          ('fugir', 'a'): 2,
#          ('a', 'um'): 39,
#          ('um', 'prólogo'): 1,
#          ('prólogo', 'explícito'): 1,
#          ('explícito', 'e'): 1,
#          ('e', 'longo'): 3,
#          ('longo', '.'): 3,
#          ('O', 'melhor'): 5,
#          ('melhor', 'prólogo'): 1,
#          ('prólogo', 'é'): 1,
#          ('que', 'contém'): 1,
#          ('contém', 'menos'): 1,
#          ('menos', 'coisas'): 1,
#          ('coisas', ','): 15,
#          ('ou', 'o'): 6,
#          ('que', 'as'): 17,
#          ('as', 'diz'): 1,
#          ('diz', 'de'): 1,
#          ('um', 'jeito'): 4,
#          ('jeito', 'obscuro'): 1,
#          ('obscuro', 'e'): 2,
#          ('e', 'truncado'): 1,
#          ('truncado', '.'): 1,
#          ('<s>', 'Conseguintemente'): 1,
#          ('Conseguintemente', ','): 1,
#          (',', 'evito'): 1,
#          ('evito', 'contar'): 1,
#          ('contar', 'o'): 1,
#          ('o', 'processo'): 1,
#          ('processo', 'extraordinário'): 1,
#          ('extraordinário', 'que'): 1,
#          ('que', 'empreguei'): 1,
#          ('empreguei', 'na'): 1,
#          ('na', 'composição'): 1,
#          ('composição', 'destas'): 1,
#          ('Memórias', ','): 1,
#          (',', 'trabalhadas'): 1,
#          ('trabalhadas', 'cá'): 1,
#          ('cá', 'no'): 1,
#          ('no', 'outro'): 3,
#          ('outro', 'mundo'): 1,
#          ('mundo', '.'): 3,
#          ('<s>', 'Seria'): 3,
#          ('Seria', 'curioso'): 1,
#          ('curioso', ','): 1,
#          ('mas', 'nimiamente'): 1,
#          ('nimiamente', 'extenso'): 1,
#          ('extenso', ','): 1,
#          ('e', 'aliás'): 5,
#          ('aliás', 'desnecessário'): 1,
#          ('desnecessário', 'ao'): 1,
#          ('ao', 'entendimento'): 1,
#          ('entendimento', 'da'): 1,
#          ('da', 'obra'): 1,
#          ('obra', '.'): 2,
#          ('A', 'obra'): 1,
#          ('obra', 'em'): 1,
#          ('em', 'si'): 8,
#          ('si', 'mesma'): 13,
#          ('mesma', 'é'): 1,
#          ('é', 'tudo'): 1,
#          ('tudo', ':'): 3,
#          (':', 'se'): 1,
#          ('se', 'te'): 5,
#          ('te', 'agradar'): 1,
#          ('agradar', ','): 2,
#          (',', 'fino'): 2,
#          ('fino', 'leitor'): 1,
#          ('leitor', ','): 8,
#          (',', 'pago'): 2,
#          ('pago', '-'): 2,
#          ('-', 'me'): 605,
#          ('me', 'da'): 9,
#          ('da', 'tarefa'): 1,
#          ('tarefa', ';'): 1,
#          (';', 'se'): 12,
#          ('te', 'não'): 5,
#          ('não', 'agradar'): 1,
#          ('-', 'te'): 26,
#          ('te', 'com'): 5,
#          ('com', 'um'): 50,
#          ('um', 'piparote'): 3,
#          ('piparote', ','): 1,
#          ('e', 'adeus'): 1,
#          ('adeus', '.'): 1,
#          ('<s>', 'Brás'): 1,
#          ('Cubas', '.'): 8,
#          ('<s>', 'CAPÍTULO'): 160,
#          ('CAPÍTULO', 'PRIMEIRO'): 1,
#          ('PRIMEIRO', '/'): 1,
#          ('/', 'ÓBITO'): 1,
#          ('ÓBITO', 'DO'): 1,
#          ('DO', 'AUTOR'): 1,
#          ('AUTOR', '</s>'): 1,
#          ('<s>', 'Algum'): 3,
#          ('Algum', 'tempo'): 2,
#          ('tempo', 'hesitei'): 1,
#          ('hesitei', 'se'): 1,
#          ('se', 'devia'): 1,
#          ('devia', 'abrir'): 1,
#          ('abrir', 'estas'): 1,
#          ('estas', 'memórias'): 1,
#          ('memórias', 'pelo'): 1,
#          ('pelo', 'princípio'): 1,
#          ('princípio', 'ou'): 1,
#          ('ou', 'pelo'): 1,
#          ('pelo', 'fim'): 1,
#          ('fim', ','): 4,
#          (',', 'isto'): 11,
#          ('isto', 'é'): 14,
#          ('é', ','): 12,
#          ('se', 'poria'): 1,
#          ('poria', 'em'): 1,
#          ('em', 'primeiro'): 1,
#          ('primeiro', 'lugar'): 2,
#          ('lugar', 'o'): 1,
#          ('o', 'meu'): 47,
#          ('meu', 'nascimento'): 1,
#          ('nascimento', 'ou'): 1,
#          ('ou', 'a'): 6,
#          ('a', 'minha'): 62,
#          ('minha', 'morte'): 2,
#          ('morte', '.'): 8,
#          ('<s>', 'Suposto'): 1,
#          ('Suposto', 'o'): 1,
#          ('o', 'uso'): 4,
#          ('uso', 'vulgar'): 1,
#          ('vulgar', 'seja'): 1,
#          ('seja', 'começar'): 1,
#          ('começar', 'pelo'): 1,
#          ('pelo', 'nascimento'): 1,
#          ('nascimento', ','): 1,
#          (',', 'duas'): 3,
#          ('duas', 'considerações'): 1,
#          ('considerações', 'me'): 1,
#          ('me', 'levaram'): 2,
#          ('levaram', 'a'): 1,
#          ('a', 'adotar'): 1,
#          ('adotar', 'diferente'): 1,
#          ('diferente', 'método'): 1,
#          ('método', ':'): 1,
#          (':', 'a'): 10,
#          ('a', 'primeira'): 16,
#          ('primeira', 'é'): 1,
#          ('que', 'eu'): 112,
#          ('eu', 'não'): 39,
#          ('não', 'sou'): 5,
#          ('sou', 'propriamente'): 1,
#          ('propriamente', 'um'): 1,
#          ('autor', 'defunto'): 1,
#          ('mas', 'um'): 10,
#          ('defunto', 'autor'): 1,
#          ('autor', ','): 1,
#          (',', 'para'): 52,
#          ('para', 'quem'): 3,
#          ('quem', 'a'): 1,
#          ('a', 'campa'): 1,
#          ('campa', 'foi'): 1,
#          ('foi', 'outro'): 2,
#          ('outro', 'berço'): 1,
#          ('berço', ';'): 1,
#          (';', 'a'): 51,
#          ('a', 'segunda'): 6,
#          ('segunda', 'é'): 1,
#          ('que', 'o'): 128,
#          ('o', 'escrito'): 1,
#          ('escrito', 'ficaria'): 1,
#          ('ficaria', 'assim'): 1,
#          ('assim', 'mais'): 1,
#          ('mais', 'galante'): 1,
#          ('galante', 'e'): 1,
#          ('mais', 'novo'): 1,
#          ('novo', '.'): 3,
#          ('<s>', 'Moisés'): 1,
#          ('Moisés', ','): 1,
#          ('que', 'também'): 6,
#          ('também', 'contou'): 1,
#          ('contou', 'a'): 1,
#          ('a', 'sua'): 26,
#          ('sua', 'morte'): 1,
#          ('morte', ','): 17,
#          ('não', 'a'): 10,
#          ('a', 'pôs'): 1,
#          ('pôs', 'no'): 2,
#          ('no', 'intróito'): 1,
#          ('intróito', ','): 1,
#          ('mas', 'no'): 4,
#          ('no', 'cabo'): 1,
#          ('cabo', ':'): 1,
#          (':', 'diferença'): 1,
#          ('diferença', 'radical'): 1,
#          ('radical', 'entre'): 1,
#          ('entre', 'este'): 1,
#          ('este', 'livro'): 5,
#          ('livro', 'e'): 4,
#          ('o', 'Pentateuco'): 1,
#          ('Pentateuco', '.'): 1,
#          ('<s>', 'Dito'): 3,
#          ('Dito', 'isto'): 2,
#          ('isto', ','): 9,
#          (',', 'expirei'): 1,
#          ('expirei', 'às'): 1,
#          ('às', 'duas'): 1,
#          ('duas', 'horas'): 5,
#          ('horas', 'da'): 4,
#          ('da', 'tarde'): 7,
#          ('tarde', 'de'): 2,
#          ('uma', 'sexta'): 1,
#          ('sexta', '-'): 2,
#          ('-', 'feira'): 4,
#          ('feira', 'do'): 1,
#          ('do', 'mês'): 1,
#          ('mês', 'de'): 1,
#          ('de', 'agosto'): 1,
#          ('agosto', 'de'): 1,
#          ('de', '1869'): 1,
#          ('1869', ','): 1,
#          ('minha', 'bela'): 1,
#          ('bela', 'chácara'): 1,
#          ('chácara', 'de'): 1,
#          ('de', 'Catumbi'): 1,
#          ('Catumbi', '.'): 1,
#          ('<s>', 'Tinha'): 18,
#          ('Tinha', 'uns'): 1,
#          ('uns', 'sessenta'): 1,
#          ('sessenta', 'e'): 2,
#          ('e', 'quatro'): 4,
#          ('quatro', 'anos'): 3,
#          ('anos', ','): 28,
#          (',', 'rijos'): 1,
#          ('rijos', 'e'): 1,
#          ('e', 'prósperos'): 1,
#          ('prósperos', ','): 1,
#          (',', 'era'): 53,
#          ('era', 'solteiro'): 1,
#          ('solteiro', ','): 2,
#          (',', 'possuía'): 3,
#          ('possuía', 'cerca'): 1,
#          ('cerca', 'de'): 2,
#          ('de', 'trezentos'): 2,
#          ('trezentos', 'contos'): 1,
#          ('contos', 'e'): 1,
#          ('e', 'fui'): 8,
#          ('fui', 'acompanhado'): 1,
#          ('acompanhado', 'ao'): 1,
#          ('ao', 'cemitério'): 4,
#          ('cemitério', 'por'): 1,
#          ('por', 'onze'): 1,
#          ('onze', 'amigos'): 1,
#          ('amigos', '.'): 2,
#          ('<s>', 'Onze'): 1,
#          ('Onze', 'amigos'): 1,
#          ('amigos', '!'): 2,
#          ('!', '</s>'): 295,
#          ('<s>', 'Verdade'): 5,
#          ('Verdade', 'é'): 5,
#          ('não', 'houve'): 4,
#          ('houve', 'cartas'): 1,
#          ('cartas', 'nem'): 1,
#          ('nem', 'anúncios'): 1,
#          ('anúncios', '.'): 1,
#          ('que', 'chovia'): 2,
#          ('chovia', '\x97'): 1,
#          ('\x97', 'peneirava'): 1,
#          ('peneirava', 'uma'): 1,
#          ('uma', 'chuvinha'): 1,
#          ('chuvinha', 'miúda'): 1,
#          ('miúda', ','): 2,
#          (',', 'triste'): 5,
#          ('triste', 'e'): 6,
#          ('e', 'constante'): 2,
#          ('constante', ','): 2,
#          (',', 'tão'): 19,
#          ('tão', 'constante'): 1,
#          ('constante', 'e'): 1,
#          ('e', 'tão'): 7,
#          ('tão', 'triste'): 5,
#          ('triste', ','): 11,
#          ('que', 'levou'): 1,
#          ('levou', 'um'): 1,
#          ('um', 'daqueles'): 1,
#          ('daqueles', 'fiéis'): 1,
#          ('fiéis', 'da'): 1,
#          ('da', 'última'): 3,
#          ('última', 'hora'): 2,
#          ('hora', 'a'): 1,
#          ('a', 'intercalar'): 2,
#          ('intercalar', 'esta'): 1,
#          ('esta', 'engenhosa'): 1,
#          ('engenhosa', 'idéia'): 1,
#          ('idéia', 'no'): 2,
#          ('no', 'discurso'): 1,
#          ('discurso', 'que'): 2,
#          ('que', 'proferiu'): 1,
#          ('proferiu', 'à'): 1,
#          ('à', 'beira'): 1,
#          ('beira', 'de'): 1,
#          ('de', 'minha'): 9,
#          ('minha', 'cova'): 1,
#          ('cova', ':'): 1,
#          (':', '\x97'): 32,
#          ('\x97', '\x93'): 10,
#          ('\x93', 'Vós'): 1,
#          ('Vós', ','): 2,
#          ('o', 'conhecestes'): 1,
#          ('conhecestes', ','): 1,
#          (',', 'meus'): 1,
#          ('meus', 'senhores'): 1,
#          ('senhores', ','): 1,
#          (',', 'vós'): 3,
#          ('vós', 'podeis'): 1,
#          ('podeis', 'dizer'): 1,
#          ('dizer', 'comigo'): 1,
#          ('comigo', 'que'): 3,
#          ('a', 'natureza'): 8,
#          ('natureza', 'parece'): 1,
#          ('parece', 'estar'): 2,
#          ('estar', 'chorando'): 1,
#          ('chorando', 'a'): 1,
#          ('a', 'perda'): 1,
#          ('perda', 'irreparável'): 1,
#          ('irreparável', 'de'): 1,
#          ('um', 'dos'): 21,
#          ('dos', 'mais'): 4,
#          ('mais', 'belos'): 2,
#          ('belos', 'caracteres'): 1,
#          ('caracteres', 'que'): 1,
#          ('que', 'têm'): 2,
#          ('têm', 'honrado'): 1,
#          ('honrado', 'a'): 1,
#          ('a', 'humanidade'): 1,
#          ('humanidade', '.'): 2,
#          ('<s>', 'Este'): 7,
#          ('Este', 'ar'): 2,
#          ('ar', 'sombrio'): 1,
#          ('sombrio', ','): 1,
#          (',', 'estas'): 2,
#          ('estas', 'gotas'): 1,
#          ('gotas', 'do'): 1,
#          ('do', 'céu'): 4,
#          ('céu', ','): 3,
#          (',', 'aquelas'): 1,
#          ('aquelas', 'nuvens'): 1,
#          ('nuvens', 'escuras'): 1,
#          ('escuras', 'que'): 1,
#          ('que', 'cobrem'): 1,
#          ('cobrem', 'o'): 1,
#          ('o', 'azul'): 1,
#          ('azul', 'como'): 1,
#          ('como', 'um'): 23,
#          ('um', 'crepe'): 1,
#          ('crepe', 'funéreo'): 1,
#          ('funéreo', ','): 1,
#          (',', 'tudo'): 9,
#          ('tudo', 'isso'): 12,
#          ('isso', 'é'): 3,
#          ('é', 'a'): 38,
#          ('a', 'dor'): 12,
#          ('dor', 'crua'): 1,
#          ('crua', 'e'): 1,
#          ('e', 'má'): 1,
#          ('má', 'que'): 1,
#          ('que', 'lhe'): 53,
#          ('lhe', 'rói'): 1,
#          ('rói', 'à'): 1,
#          ('à', 'Natureza'): 1,
#          ('Natureza', 'as'): 1,
#          ('as', 'mais'): 2,
#          ('mais', 'íntimas'): 2,
#          ('íntimas', 'entranhas'): 1,
#          ('entranhas', ';'): 1,
#          (';', 'tudo'): 3,
#          ('é', 'um'): 19,
#          ('um', 'sublime'): 1,
#          ('sublime', 'louvor'): 1,
#          ('louvor', 'ao'): 1,
#          ('ao', 'nosso'): 1,
#          ('nosso', 'ilustre'): 1,
#          ('ilustre', 'finado'): 1,
#          ('finado', '.\x94'): 1,
#          ('.\x94', '</s>'): 2,
#          ('<s>', 'Bom'): 2,
#          ('Bom', 'e'): 1,
#          ('e', 'fiel'): 1,
#          ('fiel', 'amigo'): 1,
#          ('amigo', '!'): 1,
#          ('Não', ','): 21,
#          ('não', 'me'): 37,
#          ('me', 'arrependo'): 2,
#          ('arrependo', 'das'): 1,
#          ('das', 'vinte'): 1,
#          ('vinte', 'apólices'): 1,
#          ('apólices', 'que'): 1,
#          ('lhe', 'deixei'): 1,
#          ('deixei', '.'): 1,
#          ('<s>', 'E'): 109,
#          ('E', 'foi'): 4,
#          ('foi', 'assim'): 4,
#          ('assim', 'que'): 8,
#          ('que', 'cheguei'): 4,
#          ('cheguei', 'à'): 1,
#          ('à', 'cláusula'): 1,
#          ('cláusula', 'dos'): 1,
#          ('dos', 'meus'): 15,
#          ('meus', 'dias'): 2,
#          ('dias', ';'): 4,
#          (';', 'foi'): 13,
#          ('me', 'encaminhei'): 1,
#          ('encaminhei', 'para'): 1,
#          ('para', 'o'): 38,
#          ('o', 'undiscovered'): 1,
#          ('undiscovered', 'country'): 1,
#          ('country', 'de'): 1,
#          ('de', 'Hamlet'): 2,
#          ('Hamlet', ','): 1,
#          (',', 'sem'): 77,
#          ('sem', 'as'): 2,
#          ('as', 'ânsias'): 1,
#          ('ânsias', 'nem'): 1,
#          ('nem', 'as'): 8,
#          ('as', 'dúvidas'): 1,
#          ('dúvidas', 'do'): 1,
#          ('do', 'moço'): 1,
#          ('moço', 'príncipe'): 1,
#          ('príncipe', ','): 1,
#          ('mas', 'pausado'): 1,
#          ('pausado', 'e'): 1,
#          ('e', 'trôpego'): 1,
#          ('trôpego', 'como'): 1,
#          ('como', 'quem'): 5,
#          ('quem', 'se'): 2,
#          ('se', 'retira'): 1,
#          ('retira', 'tarde'): 1,
#          ('tarde', 'do'): 1,
#          ('do', 'espetáculo'): 3,
#          ('espetáculo', '.'): 3,
#          ('<s>', 'Tarde'): 2,
#          ('Tarde', 'e'): 1,
#          ('e', 'aborrecido'): 2,
#          ('aborrecido', '.'): 3,
#          ('<s>', 'Viram'): 2,
#          ('Viram', '-'): 1,
#          ('me', 'ir'): 7,
#          ('ir', 'umas'): 1,
#          ('umas', 'nove'): 1,
#          ('nove', 'ou'): 1,
#          ('ou', 'dez'): 4,
#          ('dez', 'pessoas'): 2,
#          ('pessoas', ','): 2,
#          (',', 'entre'): 19,
#          ('entre', 'elas'): 1,
#          ('elas', 'três'): 1,
#          ('três', 'senhoras'): 2,
#          ('senhoras', ','): 3,
#          (',', 'minha'): 4,
#          ('minha', 'irmã'): 5,
#          ('irmã', 'Sabina'): 3,
#          ('Sabina', ','): 10,
#          ...})

# %% [markdown]
# Precisamos também contar os trigramas, assim, use o Counter nos trigramas na linha abaixo.

# %%
count_trigram = Counter(words_trigram)

# %% [markdown]
# Criaremos uma lista de bigramas e trigramas únicos para podermos gerar nosso modelo. Utilizaremos essa lista como chave do nosso dicionário de contagem.

# %%
bigram_key = list(count_bigram.keys())
trigram_key = list(count_trigram.keys())

# %%
trigram_key
# Out:
# [('<s>', '<s>', 'Romance'),
#  ('<s>', 'Romance', ','),
#  ('Romance', ',', 'Memórias'),
#  (',', 'Memórias', 'Póstumas'),
#  ('Memórias', 'Póstumas', 'de'),
#  ('Póstumas', 'de', 'Brás'),
#  ('de', 'Brás', 'Cubas'),
#  ('Brás', 'Cubas', ','),
#  ('Cubas', ',', '1880'),
#  (',', '1880', '</s>'),
#  ('1880', '</s>', '<s>'),
#  ('</s>', '<s>', '<s>'),
#  ('<s>', '<s>', 'Memórias'),
#  ('<s>', 'Memórias', 'Póstumas'),
#  ('Brás', 'Cubas', '</s>'),
#  ('Cubas', '</s>', '<s>'),
#  ('<s>', '<s>', 'Texto'),
#  ('<s>', 'Texto', '-'),
#  ('Texto', '-', 'fonte'),
#  ('-', 'fonte', ':'),
#  ('fonte', ':', 'Obra'),
#  (':', 'Obra', 'Completa'),
#  ('Obra', 'Completa', ','),
#  ('Completa', ',', 'Machado'),
#  (',', 'Machado', 'de'),
#  ('Machado', 'de', 'Assis'),
#  ('de', 'Assis', ','),
#  ('Assis', ',', 'Rio'),
#  (',', 'Rio', 'de'),
#  ('Rio', 'de', 'Janeiro'),
#  ('de', 'Janeiro', ':'),
#  ('Janeiro', ':', 'Editora'),
#  (':', 'Editora', 'Nova'),
#  ('Editora', 'Nova', 'Aguilar'),
#  ('Nova', 'Aguilar', ','),
#  ('Aguilar', ',', '1994'),
#  (',', '1994', '.'),
#  ('1994', '.', '</s>'),
#  ('.', '</s>', '<s>'),
#  ('<s>', '<s>', 'Publicado'),
#  ('<s>', 'Publicado', 'originalmente'),
#  ('Publicado', 'originalmente', 'em'),
#  ('originalmente', 'em', 'folhetins'),
#  ('em', 'folhetins', ','),
#  ('folhetins', ',', 'a'),
#  (',', 'a', 'partir'),
#  ('a', 'partir', 'de'),
#  ('partir', 'de', 'março'),
#  ('de', 'março', 'de'),
#  ('março', 'de', '1880'),
#  ('de', '1880', ','),
#  ('1880', ',', 'na'),
#  (',', 'na', 'Revista'),
#  ('na', 'Revista', 'Brasileira'),
#  ('Revista', 'Brasileira', '.'),
#  ('Brasileira', '.', '</s>'),
#  ('<s>', '<s>', 'Ao'),
#  ('<s>', 'Ao', 'verme'),
#  ('Ao', 'verme', 'que'),
#  ('verme', 'que', 'primeiro'),
#  ('que', 'primeiro', 'roeu'),
#  ('primeiro', 'roeu', 'as'),
#  ('roeu', 'as', 'frias'),
#  ('as', 'frias', 'carnes'),
#  ('frias', 'carnes', 'do'),
#  ('carnes', 'do', 'meu'),
#  ('do', 'meu', 'cadáver'),
#  ('meu', 'cadáver', '</s>'),
#  ('cadáver', '</s>', '<s>'),
#  ('<s>', '<s>', 'dedico'),
#  ('<s>', 'dedico', 'como'),
#  ('dedico', 'como', 'saudosa'),
#  ('como', 'saudosa', 'lembrança'),
#  ('saudosa', 'lembrança', '</s>'),
#  ('lembrança', '</s>', '<s>'),
#  ('<s>', '<s>', 'estas'),
#  ('<s>', 'estas', 'Memórias'),
#  ('estas', 'Memórias', 'Póstumas'),
#  ('Memórias', 'Póstumas', '</s>'),
#  ('Póstumas', '</s>', '<s>'),
#  ('<s>', '<s>', 'Prólogo'),
#  ('<s>', 'Prólogo', 'da'),
#  ('Prólogo', 'da', 'terceira'),
#  ('da', 'terceira', 'edição'),
#  ('terceira', 'edição', '</s>'),
#  ('edição', '</s>', '<s>'),
#  ('<s>', '<s>', 'A'),
#  ('<s>', 'A', 'primeira'),
#  ('A', 'primeira', 'edição'),
#  ('primeira', 'edição', 'destas'),
#  ('edição', 'destas', 'Memórias'),
#  ('destas', 'Memórias', 'Póstumas'),
#  ('Brás', 'Cubas', 'foi'),
#  ('Cubas', 'foi', 'feita'),
#  ('foi', 'feita', 'aos'),
#  ('feita', 'aos', 'pedaços'),
#  ('aos', 'pedaços', 'na'),
#  ('pedaços', 'na', 'Revista'),
#  ('Revista', 'Brasileira', ','),
#  ('Brasileira', ',', 'pelos'),
#  (',', 'pelos', 'anos'),
#  ('pelos', 'anos', 'de'),
#  ('anos', 'de', '1880'),
#  ('de', '1880', '.'),
#  ('1880', '.', '</s>'),
#  ('<s>', '<s>', 'Postas'),
#  ('<s>', 'Postas', 'mais'),
#  ('Postas', 'mais', 'tarde'),
#  ('mais', 'tarde', 'em'),
#  ('tarde', 'em', 'livro'),
#  ('em', 'livro', ','),
#  ('livro', ',', 'corrigi'),
#  (',', 'corrigi', 'o'),
#  ('corrigi', 'o', 'texto'),
#  ('o', 'texto', 'em'),
#  ('texto', 'em', 'vários'),
#  ('em', 'vários', 'lugares'),
#  ('vários', 'lugares', '.'),
#  ('lugares', '.', '</s>'),
#  ('<s>', '<s>', 'Agora'),
#  ('<s>', 'Agora', 'que'),
#  ('Agora', 'que', 'tive'),
#  ('que', 'tive', 'de'),
#  ('tive', 'de', 'o'),
#  ('de', 'o', 'rever'),
#  ('o', 'rever', 'para'),
#  ('rever', 'para', 'a'),
#  ('para', 'a', 'terceira'),
#  ('a', 'terceira', 'edição'),
#  ('terceira', 'edição', ','),
#  ('edição', ',', 'emendei'),
#  (',', 'emendei', 'ainda'),
#  ('emendei', 'ainda', 'alguma'),
#  ('ainda', 'alguma', 'coisa'),
#  ('alguma', 'coisa', 'e'),
#  ('coisa', 'e', 'suprimi'),
#  ('e', 'suprimi', 'duas'),
#  ('suprimi', 'duas', 'ou'),
#  ('duas', 'ou', 'três'),
#  ('ou', 'três', 'dúzias'),
#  ('três', 'dúzias', 'de'),
#  ('dúzias', 'de', 'linhas'),
#  ('de', 'linhas', '.'),
#  ('linhas', '.', '</s>'),
#  ('<s>', '<s>', 'Assim'),
#  ('<s>', 'Assim', 'composta'),
#  ('Assim', 'composta', ','),
#  ('composta', ',', 'sai'),
#  (',', 'sai', 'novamente'),
#  ('sai', 'novamente', 'à'),
#  ('novamente', 'à', 'luz'),
#  ('à', 'luz', 'esta'),
#  ('luz', 'esta', 'obra'),
#  ('esta', 'obra', 'que'),
#  ('obra', 'que', 'alguma'),
#  ('que', 'alguma', 'benevolência'),
#  ('alguma', 'benevolência', 'parece'),
#  ('benevolência', 'parece', 'ter'),
#  ('parece', 'ter', 'encontrado'),
#  ('ter', 'encontrado', 'no'),
#  ('encontrado', 'no', 'público'),
#  ('no', 'público', '.'),
#  ('público', '.', '</s>'),
#  ('<s>', '<s>', 'Capistrano'),
#  ('<s>', 'Capistrano', 'de'),
#  ('Capistrano', 'de', 'Abreu'),
#  ('de', 'Abreu', ','),
#  ('Abreu', ',', 'noticiando'),
#  (',', 'noticiando', 'a'),
#  ('noticiando', 'a', 'publicação'),
#  ('a', 'publicação', 'do'),
#  ('publicação', 'do', 'livro'),
#  ('do', 'livro', ','),
#  ('livro', ',', 'perguntava'),
#  (',', 'perguntava', ':'),
#  ('perguntava', ':', '\x93'),
#  (':', '\x93', 'As'),
#  ('\x93', 'As', 'Memórias'),
#  ('As', 'Memórias', 'Póstumas'),
#  ('Brás', 'Cubas', 'são'),
#  ('Cubas', 'são', 'um'),
#  ('são', 'um', 'romance'),
#  ('um', 'romance', '?\x94'),
#  ('romance', '?\x94', 'Macedo'),
#  ('?\x94', 'Macedo', 'Soares'),
#  ('Macedo', 'Soares', ','),
#  ('Soares', ',', 'em'),
#  (',', 'em', 'carta'),
#  ('em', 'carta', 'que'),
#  ('carta', 'que', 'me'),
#  ('que', 'me', 'escreveu'),
#  ('me', 'escreveu', 'por'),
#  ('escreveu', 'por', 'esse'),
#  ('por', 'esse', 'tempo'),
#  ('esse', 'tempo', ','),
#  ('tempo', ',', 'recordava'),
#  (',', 'recordava', 'amigamente'),
#  ('recordava', 'amigamente', 'as'),
#  ('amigamente', 'as', 'Viagens'),
#  ('as', 'Viagens', 'na'),
#  ('Viagens', 'na', 'minha'),
#  ('na', 'minha', 'terra'),
#  ('minha', 'terra', '.'),
#  ('terra', '.', '</s>'),
#  ('<s>', 'Ao', 'primeiro'),
#  ('Ao', 'primeiro', 'respondia'),
#  ('primeiro', 'respondia', 'já'),
#  ('respondia', 'já', 'o'),
#  ('já', 'o', 'defunto'),
#  ('o', 'defunto', 'Brás'),
#  ('defunto', 'Brás', 'Cubas'),
#  ('Brás', 'Cubas', '('),
#  ('Cubas', '(', 'como'),
#  ('(', 'como', 'o'),
#  ('como', 'o', 'leitor'),
#  ('o', 'leitor', 'viu'),
#  ('leitor', 'viu', 'e'),
#  ('viu', 'e', 'verá'),
#  ('e', 'verá', 'no'),
#  ('verá', 'no', 'prólogo'),
#  ('no', 'prólogo', 'dele'),
#  ('prólogo', 'dele', 'que'),
#  ('dele', 'que', 'vai'),
#  ('que', 'vai', 'adiante'),
#  ('vai', 'adiante', ')'),
#  ('adiante', ')', 'que'),
#  (')', 'que', 'sim'),
#  ('que', 'sim', 'e'),
#  ('sim', 'e', 'que'),
#  ('e', 'que', 'não'),
#  ('que', 'não', ','),
#  ('não', ',', 'que'),
#  (',', 'que', 'era'),
#  ('que', 'era', 'romance'),
#  ('era', 'romance', 'para'),
#  ('romance', 'para', 'uns'),
#  ('para', 'uns', 'e'),
#  ('uns', 'e', 'não'),
#  ('e', 'não', 'o'),
#  ('não', 'o', 'era'),
#  ('o', 'era', 'para'),
#  ('era', 'para', 'outros'),
#  ('para', 'outros', '.'),
#  ('outros', '.', '</s>'),
#  ('<s>', '<s>', 'Quanto'),
#  ('<s>', 'Quanto', 'ao'),
#  ('Quanto', 'ao', 'segundo'),
#  ('ao', 'segundo', ','),
#  ('segundo', ',', 'assim'),
#  (',', 'assim', 'se'),
#  ('assim', 'se', 'explicou'),
#  ('se', 'explicou', 'o'),
#  ('explicou', 'o', 'finado'),
#  ('o', 'finado', ':'),
#  ('finado', ':', '\x93'),
#  (':', '\x93', 'Trata'),
#  ('\x93', 'Trata', '-'),
#  ('Trata', '-', 'se'),
#  ('-', 'se', 'de'),
#  ('se', 'de', 'uma'),
#  ('de', 'uma', 'obra'),
#  ('uma', 'obra', 'difusa'),
#  ('obra', 'difusa', ','),
#  ('difusa', ',', 'na'),
#  (',', 'na', 'qual'),
#  ('na', 'qual', 'eu'),
#  ('qual', 'eu', ','),
#  ('eu', ',', 'Brás'),
#  (',', 'Brás', 'Cubas'),
#  ('Cubas', ',', 'se'),
#  (',', 'se', 'adotei'),
#  ('se', 'adotei', 'a'),
#  ('adotei', 'a', 'forma'),
#  ('a', 'forma', 'livre'),
#  ('forma', 'livre', 'de'),
#  ('livre', 'de', 'um'),
#  ('de', 'um', 'Sterne'),
#  ('um', 'Sterne', 'ou'),
#  ('Sterne', 'ou', 'de'),
#  ('ou', 'de', 'um'),
#  ('de', 'um', 'Xavier'),
#  ('um', 'Xavier', 'de'),
#  ('Xavier', 'de', 'Maistre'),
#  ('de', 'Maistre', ','),
#  ('Maistre', ',', 'não'),
#  (',', 'não', 'sei'),
#  ('não', 'sei', 'se'),
#  ('sei', 'se', 'lhe'),
#  ('se', 'lhe', 'meti'),
#  ('lhe', 'meti', 'algumas'),
#  ('meti', 'algumas', 'rabugens'),
#  ('algumas', 'rabugens', 'de'),
#  ('rabugens', 'de', 'pessimismo'),
#  ('de', 'pessimismo', '.\x94'),
#  ('pessimismo', '.\x94', 'Toda'),
#  ('.\x94', 'Toda', 'essa'),
#  ('Toda', 'essa', 'gente'),
#  ('essa', 'gente', 'viajou'),
#  ('gente', 'viajou', ':'),
#  ('viajou', ':', 'Xavier'),
#  (':', 'Xavier', 'de'),
#  ('de', 'Maistre', 'à'),
#  ('Maistre', 'à', 'roda'),
#  ('à', 'roda', 'do'),
#  ('roda', 'do', 'quarto'),
#  ('do', 'quarto', ','),
#  ('quarto', ',', 'Garret'),
#  (',', 'Garret', 'na'),
#  ('Garret', 'na', 'terra'),
#  ('na', 'terra', 'dele'),
#  ('terra', 'dele', ','),
#  ('dele', ',', 'Sterne'),
#  (',', 'Sterne', 'na'),
#  ('Sterne', 'na', 'terra'),
#  ('na', 'terra', 'dos'),
#  ('terra', 'dos', 'outros'),
#  ('dos', 'outros', '.'),
#  ('<s>', '<s>', 'De'),
#  ('<s>', 'De', 'Brás'),
#  ('De', 'Brás', 'Cubas'),
#  ('Brás', 'Cubas', 'se'),
#  ('Cubas', 'se', 'pode'),
#  ('se', 'pode', 'dizer'),
#  ('pode', 'dizer', 'que'),
#  ('dizer', 'que', 'viajou'),
#  ('que', 'viajou', 'à'),
#  ('viajou', 'à', 'roda'),
#  ('à', 'roda', 'da'),
#  ('roda', 'da', 'vida'),
#  ('da', 'vida', '.'),
#  ('vida', '.', '</s>'),
#  ('<s>', '<s>', 'O'),
#  ('<s>', 'O', 'que'),
#  ('O', 'que', 'faz'),
#  ('que', 'faz', 'do'),
#  ('faz', 'do', 'meu'),
#  ('do', 'meu', 'Brás'),
#  ('meu', 'Brás', 'Cubas'),
#  ('Brás', 'Cubas', 'um'),
#  ('Cubas', 'um', 'autor'),
#  ('um', 'autor', 'particular'),
#  ('autor', 'particular', 'é'),
#  ('particular', 'é', 'o'),
#  ('é', 'o', 'que'),
#  ('o', 'que', 'ele'),
#  ('que', 'ele', 'chama'),
#  ('ele', 'chama', '\x93'),
#  ('chama', '\x93', 'rabugens'),
#  ('\x93', 'rabugens', 'de'),
#  ('de', 'pessimismo', '\x94.'),
#  ('pessimismo', '\x94.', '</s>'),
#  ('\x94.', '</s>', '<s>'),
#  ('<s>', '<s>', 'Há'),
#  ('<s>', 'Há', 'na'),
#  ('Há', 'na', 'alma'),
#  ('na', 'alma', 'deste'),
#  ('alma', 'deste', 'livro'),
#  ('deste', 'livro', ','),
#  ('livro', ',', 'por'),
#  (',', 'por', 'mais'),
#  ('por', 'mais', 'risonho'),
#  ('mais', 'risonho', 'que'),
#  ('risonho', 'que', 'pareça'),
#  ('que', 'pareça', ','),
#  ('pareça', ',', 'um'),
#  (',', 'um', 'sentimento'),
#  ('um', 'sentimento', 'amargo'),
#  ('sentimento', 'amargo', 'e'),
#  ('amargo', 'e', 'áspero'),
#  ('e', 'áspero', ','),
#  ('áspero', ',', 'que'),
#  (',', 'que', 'está'),
#  ('que', 'está', 'longe'),
#  ('está', 'longe', 'de'),
#  ('longe', 'de', 'vir'),
#  ('de', 'vir', 'de'),
#  ('vir', 'de', 'seus'),
#  ('de', 'seus', 'modelos'),
#  ('seus', 'modelos', '.'),
#  ('modelos', '.', '</s>'),
#  ('<s>', '<s>', 'É'),
#  ('<s>', 'É', 'taça'),
#  ('É', 'taça', 'que'),
#  ('taça', 'que', 'pode'),
#  ('que', 'pode', 'ter'),
#  ('pode', 'ter', 'lavores'),
#  ('ter', 'lavores', 'de'),
#  ('lavores', 'de', 'igual'),
#  ('de', 'igual', 'escola'),
#  ('igual', 'escola', ','),
#  ('escola', ',', 'mas'),
#  (',', 'mas', 'leva'),
#  ('mas', 'leva', 'outro'),
#  ('leva', 'outro', 'vinho'),
#  ('outro', 'vinho', '.'),
#  ('vinho', '.', '</s>'),
#  ('<s>', '<s>', 'Não'),
#  ('<s>', 'Não', 'digo'),
#  ('Não', 'digo', 'mais'),
#  ('digo', 'mais', 'para'),
#  ('mais', 'para', 'não'),
#  ('para', 'não', 'entrar'),
#  ('não', 'entrar', 'na'),
#  ('entrar', 'na', 'crítica'),
#  ('na', 'crítica', 'de'),
#  ('crítica', 'de', 'um'),
#  ('de', 'um', 'defunto'),
#  ('um', 'defunto', ','),
#  ('defunto', ',', 'que'),
#  (',', 'que', 'se'),
#  ('que', 'se', 'pintou'),
#  ('se', 'pintou', 'a'),
#  ('pintou', 'a', 'si'),
#  ('a', 'si', 'e'),
#  ('si', 'e', 'a'),
#  ('e', 'a', 'outros'),
#  ('a', 'outros', ','),
#  ('outros', ',', 'conforme'),
#  (',', 'conforme', 'lhe'),
#  ('conforme', 'lhe', 'pareceu'),
#  ('lhe', 'pareceu', 'melhor'),
#  ('pareceu', 'melhor', 'e'),
#  ('melhor', 'e', 'mais'),
#  ('e', 'mais', 'certo'),
#  ('mais', 'certo', '.'),
#  ('certo', '.', '</s>'),
#  ('<s>', '<s>', 'Machado'),
#  ('<s>', 'Machado', 'de'),
#  ('de', 'Assis', '.'),
#  ('Assis', '.', '</s>'),
#  ('<s>', '<s>', 'AO'),
#  ('<s>', 'AO', 'LEITOR'),
#  ('AO', 'LEITOR', '</s>'),
#  ('LEITOR', '</s>', '<s>'),
#  ('<s>', '<s>', 'Que'),
#  ('<s>', 'Que', 'Stendhal'),
#  ('Que', 'Stendhal', 'confessasse'),
#  ('Stendhal', 'confessasse', 'haver'),
#  ('confessasse', 'haver', 'escrito'),
#  ('haver', 'escrito', 'um'),
#  ('escrito', 'um', 'de'),
#  ('um', 'de', 'seus'),
#  ('de', 'seus', 'livros'),
#  ('seus', 'livros', 'para'),
#  ('livros', 'para', 'cem'),
#  ('para', 'cem', 'leitores'),
#  ('cem', 'leitores', ','),
#  ('leitores', ',', 'coisa'),
#  (',', 'coisa', 'é'),
#  ('coisa', 'é', 'que'),
#  ('é', 'que', 'admira'),
#  ('que', 'admira', 'e'),
#  ('admira', 'e', 'consterna'),
#  ('e', 'consterna', '.'),
#  ('consterna', '.', '</s>'),
#  ('O', 'que', 'não'),
#  ('que', 'não', 'admira'),
#  ('não', 'admira', ','),
#  ('admira', ',', 'nem'),
#  (',', 'nem', 'provavelmente'),
#  ('nem', 'provavelmente', 'consternará'),
#  ('provavelmente', 'consternará', 'é'),
#  ('consternará', 'é', 'se'),
#  ('é', 'se', 'este'),
#  ('se', 'este', 'outro'),
#  ('este', 'outro', 'livro'),
#  ('outro', 'livro', 'não'),
#  ('livro', 'não', 'tiver'),
#  ('não', 'tiver', 'os'),
#  ('tiver', 'os', 'cem'),
#  ('os', 'cem', 'leitores'),
#  ('cem', 'leitores', 'de'),
#  ('leitores', 'de', 'Stendhal'),
#  ('de', 'Stendhal', ','),
#  ('Stendhal', ',', 'nem'),
#  (',', 'nem', 'cinqüenta'),
#  ('nem', 'cinqüenta', ','),
#  ('cinqüenta', ',', 'nem'),
#  (',', 'nem', 'vinte'),
#  ('nem', 'vinte', 'e'),
#  ('vinte', 'e', ','),
#  ('e', ',', 'quando'),
#  (',', 'quando', 'muito'),
#  ('quando', 'muito', ','),
#  ('muito', ',', 'dez'),
#  (',', 'dez', '.'),
#  ('dez', '.', '</s>'),
#  ('<s>', '<s>', 'Dez'),
#  ('<s>', 'Dez', '?'),
#  ('Dez', '?', '</s>'),
#  ('?', '</s>', '<s>'),
#  ('<s>', '<s>', 'Talvez'),
#  ('<s>', 'Talvez', 'cinco'),
#  ('Talvez', 'cinco', '.'),
#  ('cinco', '.', '</s>'),
#  ('<s>', '<s>', 'Trata'),
#  ('<s>', 'Trata', '-'),
#  ('-', 'se', ','),
#  ('se', ',', 'na'),
#  (',', 'na', 'verdade'),
#  ('na', 'verdade', ','),
#  ('verdade', ',', 'de'),
#  (',', 'de', 'uma'),
#  ('um', 'Sterne', ','),
#  ('Sterne', ',', 'ou'),
#  (',', 'ou', 'de'),
#  ('de', 'pessimismo', '.'),
#  ('pessimismo', '.', '</s>'),
#  ('<s>', '<s>', 'Pode'),
#  ('<s>', 'Pode', 'ser'),
#  ('Pode', 'ser', '.'),
#  ('ser', '.', '</s>'),
#  ('<s>', '<s>', 'Obra'),
#  ('<s>', 'Obra', 'de'),
#  ('Obra', 'de', 'finado'),
#  ('de', 'finado', '.'),
#  ('finado', '.', '</s>'),
#  ('<s>', '<s>', 'Escrevi'),
#  ('<s>', 'Escrevi', '-'),
#  ('Escrevi', '-', 'a'),
#  ('-', 'a', 'com'),
#  ('a', 'com', 'a'),
#  ('com', 'a', 'pena'),
#  ('a', 'pena', 'da'),
#  ('pena', 'da', 'galhofa'),
#  ('da', 'galhofa', 'e'),
#  ('galhofa', 'e', 'a'),
#  ('e', 'a', 'tinta'),
#  ('a', 'tinta', 'da'),
#  ('tinta', 'da', 'melancolia'),
#  ('da', 'melancolia', ','),
#  ('melancolia', ',', 'e'),
#  (',', 'e', 'não'),
#  ('e', 'não', 'é'),
#  ('não', 'é', 'difícil'),
#  ('é', 'difícil', 'antever'),
#  ('difícil', 'antever', 'o'),
#  ('antever', 'o', 'que'),
#  ('o', 'que', 'poderá'),
#  ('que', 'poderá', 'sair'),
#  ('poderá', 'sair', 'desse'),
#  ('sair', 'desse', 'conúbio'),
#  ('desse', 'conúbio', '.'),
#  ('conúbio', '.', '</s>'),
#  ('<s>', '<s>', 'Acresce'),
#  ('<s>', 'Acresce', 'que'),
#  ('Acresce', 'que', 'a'),
#  ('que', 'a', 'gente'),
#  ('a', 'gente', 'grave'),
#  ('gente', 'grave', 'achará'),
#  ('grave', 'achará', 'no'),
#  ('achará', 'no', 'livro'),
#  ('no', 'livro', 'umas'),
#  ('livro', 'umas', 'aparências'),
#  ('umas', 'aparências', 'de'),
#  ('aparências', 'de', 'puro'),
#  ('de', 'puro', 'romance'),
#  ('puro', 'romance', ','),
#  ('romance', ',', 'ao'),
#  (',', 'ao', 'passo'),
#  ('ao', 'passo', 'que'),
#  ('passo', 'que', 'a'),
#  ('a', 'gente', 'frívola'),
#  ('gente', 'frívola', 'não'),
#  ('frívola', 'não', 'achará'),
#  ('não', 'achará', 'nele'),
#  ('achará', 'nele', 'o'),
#  ('nele', 'o', 'seu'),
#  ('o', 'seu', 'romance'),
#  ('seu', 'romance', 'usual'),
#  ('romance', 'usual', ';'),
#  ('usual', ';', 'ei'),
#  (';', 'ei', '-'),
#  ('ei', '-', 'lo'),
#  ('-', 'lo', 'aí'),
#  ('lo', 'aí', 'fica'),
#  ('aí', 'fica', 'privado'),
#  ('fica', 'privado', 'da'),
#  ('privado', 'da', 'estima'),
#  ('da', 'estima', 'dos'),
#  ('estima', 'dos', 'graves'),
#  ('dos', 'graves', 'e'),
#  ('graves', 'e', 'do'),
#  ('e', 'do', 'amor'),
#  ('do', 'amor', 'dos'),
#  ('amor', 'dos', 'frívolos'),
#  ('dos', 'frívolos', ','),
#  ('frívolos', ',', 'que'),
#  (',', 'que', 'são'),
#  ('que', 'são', 'as'),
#  ('são', 'as', 'duas'),
#  ('as', 'duas', 'colunas'),
#  ('duas', 'colunas', 'máximas'),
#  ('colunas', 'máximas', 'da'),
#  ('máximas', 'da', 'opinião'),
#  ('da', 'opinião', '.'),
#  ('opinião', '.', '</s>'),
#  ('<s>', '<s>', 'Mas'),
#  ('<s>', 'Mas', 'eu'),
#  ('Mas', 'eu', 'ainda'),
#  ('eu', 'ainda', 'espero'),
#  ('ainda', 'espero', 'angariar'),
#  ('espero', 'angariar', 'as'),
#  ('angariar', 'as', 'simpatias'),
#  ('as', 'simpatias', 'da'),
#  ('simpatias', 'da', 'opinião'),
#  ('da', 'opinião', ','),
#  ('opinião', ',', 'e'),
#  (',', 'e', 'o'),
#  ('e', 'o', 'primeiro'),
#  ('o', 'primeiro', 'remédio'),
#  ('primeiro', 'remédio', 'é'),
#  ('remédio', 'é', 'fugir'),
#  ('é', 'fugir', 'a'),
#  ('fugir', 'a', 'um'),
#  ('a', 'um', 'prólogo'),
#  ('um', 'prólogo', 'explícito'),
#  ('prólogo', 'explícito', 'e'),
#  ('explícito', 'e', 'longo'),
#  ('e', 'longo', '.'),
#  ('longo', '.', '</s>'),
#  ('<s>', 'O', 'melhor'),
#  ('O', 'melhor', 'prólogo'),
#  ('melhor', 'prólogo', 'é'),
#  ('prólogo', 'é', 'o'),
#  ('o', 'que', 'contém'),
#  ('que', 'contém', 'menos'),
#  ('contém', 'menos', 'coisas'),
#  ('menos', 'coisas', ','),
#  ('coisas', ',', 'ou'),
#  (',', 'ou', 'o'),
#  ('ou', 'o', 'que'),
#  ('o', 'que', 'as'),
#  ('que', 'as', 'diz'),
#  ('as', 'diz', 'de'),
#  ('diz', 'de', 'um'),
#  ('de', 'um', 'jeito'),
#  ('um', 'jeito', 'obscuro'),
#  ('jeito', 'obscuro', 'e'),
#  ('obscuro', 'e', 'truncado'),
#  ('e', 'truncado', '.'),
#  ('truncado', '.', '</s>'),
#  ('<s>', '<s>', 'Conseguintemente'),
#  ('<s>', 'Conseguintemente', ','),
#  ('Conseguintemente', ',', 'evito'),
#  (',', 'evito', 'contar'),
#  ('evito', 'contar', 'o'),
#  ('contar', 'o', 'processo'),
#  ('o', 'processo', 'extraordinário'),
#  ('processo', 'extraordinário', 'que'),
#  ('extraordinário', 'que', 'empreguei'),
#  ('que', 'empreguei', 'na'),
#  ('empreguei', 'na', 'composição'),
#  ('na', 'composição', 'destas'),
#  ('composição', 'destas', 'Memórias'),
#  ('destas', 'Memórias', ','),
#  ('Memórias', ',', 'trabalhadas'),
#  (',', 'trabalhadas', 'cá'),
#  ('trabalhadas', 'cá', 'no'),
#  ('cá', 'no', 'outro'),
#  ('no', 'outro', 'mundo'),
#  ('outro', 'mundo', '.'),
#  ('mundo', '.', '</s>'),
#  ('<s>', '<s>', 'Seria'),
#  ('<s>', 'Seria', 'curioso'),
#  ('Seria', 'curioso', ','),
#  ('curioso', ',', 'mas'),
#  (',', 'mas', 'nimiamente'),
#  ('mas', 'nimiamente', 'extenso'),
#  ('nimiamente', 'extenso', ','),
#  ('extenso', ',', 'e'),
#  (',', 'e', 'aliás'),
#  ('e', 'aliás', 'desnecessário'),
#  ('aliás', 'desnecessário', 'ao'),
#  ('desnecessário', 'ao', 'entendimento'),
#  ('ao', 'entendimento', 'da'),
#  ('entendimento', 'da', 'obra'),
#  ('da', 'obra', '.'),
#  ('obra', '.', '</s>'),
#  ('<s>', 'A', 'obra'),
#  ('A', 'obra', 'em'),
#  ('obra', 'em', 'si'),
#  ('em', 'si', 'mesma'),
#  ('si', 'mesma', 'é'),
#  ('mesma', 'é', 'tudo'),
#  ('é', 'tudo', ':'),
#  ('tudo', ':', 'se'),
#  (':', 'se', 'te'),
#  ('se', 'te', 'agradar'),
#  ('te', 'agradar', ','),
#  ('agradar', ',', 'fino'),
#  (',', 'fino', 'leitor'),
#  ('fino', 'leitor', ','),
#  ('leitor', ',', 'pago'),
#  (',', 'pago', '-'),
#  ('pago', '-', 'me'),
#  ('-', 'me', 'da'),
#  ('me', 'da', 'tarefa'),
#  ('da', 'tarefa', ';'),
#  ('tarefa', ';', 'se'),
#  (';', 'se', 'te'),
#  ('se', 'te', 'não'),
#  ('te', 'não', 'agradar'),
#  ('não', 'agradar', ','),
#  ('agradar', ',', 'pago'),
#  ('pago', '-', 'te'),
#  ('-', 'te', 'com'),
#  ('te', 'com', 'um'),
#  ('com', 'um', 'piparote'),
#  ('um', 'piparote', ','),
#  ('piparote', ',', 'e'),
#  (',', 'e', 'adeus'),
#  ('e', 'adeus', '.'),
#  ('adeus', '.', '</s>'),
#  ('<s>', '<s>', 'Brás'),
#  ('<s>', 'Brás', 'Cubas'),
#  ('Brás', 'Cubas', '.'),
#  ('Cubas', '.', '</s>'),
#  ('<s>', '<s>', 'CAPÍTULO'),
#  ('<s>', 'CAPÍTULO', 'PRIMEIRO'),
#  ('CAPÍTULO', 'PRIMEIRO', '/'),
#  ('PRIMEIRO', '/', 'ÓBITO'),
#  ('/', 'ÓBITO', 'DO'),
#  ('ÓBITO', 'DO', 'AUTOR'),
#  ('DO', 'AUTOR', '</s>'),
#  ('AUTOR', '</s>', '<s>'),
#  ('<s>', '<s>', 'Algum'),
#  ('<s>', 'Algum', 'tempo'),
#  ('Algum', 'tempo', 'hesitei'),
#  ('tempo', 'hesitei', 'se'),
#  ('hesitei', 'se', 'devia'),
#  ('se', 'devia', 'abrir'),
#  ('devia', 'abrir', 'estas'),
#  ('abrir', 'estas', 'memórias'),
#  ('estas', 'memórias', 'pelo'),
#  ('memórias', 'pelo', 'princípio'),
#  ('pelo', 'princípio', 'ou'),
#  ('princípio', 'ou', 'pelo'),
#  ('ou', 'pelo', 'fim'),
#  ('pelo', 'fim', ','),
#  ('fim', ',', 'isto'),
#  (',', 'isto', 'é'),
#  ('isto', 'é', ','),
#  ('é', ',', 'se'),
#  (',', 'se', 'poria'),
#  ('se', 'poria', 'em'),
#  ('poria', 'em', 'primeiro'),
#  ('em', 'primeiro', 'lugar'),
#  ('primeiro', 'lugar', 'o'),
#  ('lugar', 'o', 'meu'),
#  ('o', 'meu', 'nascimento'),
#  ('meu', 'nascimento', 'ou'),
#  ('nascimento', 'ou', 'a'),
#  ('ou', 'a', 'minha'),
#  ('a', 'minha', 'morte'),
#  ('minha', 'morte', '.'),
#  ('morte', '.', '</s>'),
#  ('<s>', '<s>', 'Suposto'),
#  ('<s>', 'Suposto', 'o'),
#  ('Suposto', 'o', 'uso'),
#  ('o', 'uso', 'vulgar'),
#  ('uso', 'vulgar', 'seja'),
#  ('vulgar', 'seja', 'começar'),
#  ('seja', 'começar', 'pelo'),
#  ('começar', 'pelo', 'nascimento'),
#  ('pelo', 'nascimento', ','),
#  ('nascimento', ',', 'duas'),
#  (',', 'duas', 'considerações'),
#  ('duas', 'considerações', 'me'),
#  ('considerações', 'me', 'levaram'),
#  ('me', 'levaram', 'a'),
#  ('levaram', 'a', 'adotar'),
#  ('a', 'adotar', 'diferente'),
#  ('adotar', 'diferente', 'método'),
#  ('diferente', 'método', ':'),
#  ('método', ':', 'a'),
#  (':', 'a', 'primeira'),
#  ('a', 'primeira', 'é'),
#  ('primeira', 'é', 'que'),
#  ('é', 'que', 'eu'),
#  ('que', 'eu', 'não'),
#  ('eu', 'não', 'sou'),
#  ('não', 'sou', 'propriamente'),
#  ('sou', 'propriamente', 'um'),
#  ('propriamente', 'um', 'autor'),
#  ('um', 'autor', 'defunto'),
#  ('autor', 'defunto', ','),
#  ('defunto', ',', 'mas'),
#  (',', 'mas', 'um'),
#  ('mas', 'um', 'defunto'),
#  ('um', 'defunto', 'autor'),
#  ('defunto', 'autor', ','),
#  ('autor', ',', 'para'),
#  (',', 'para', 'quem'),
#  ('para', 'quem', 'a'),
#  ('quem', 'a', 'campa'),
#  ('a', 'campa', 'foi'),
#  ('campa', 'foi', 'outro'),
#  ('foi', 'outro', 'berço'),
#  ('outro', 'berço', ';'),
#  ('berço', ';', 'a'),
#  (';', 'a', 'segunda'),
#  ('a', 'segunda', 'é'),
#  ('segunda', 'é', 'que'),
#  ('é', 'que', 'o'),
#  ('que', 'o', 'escrito'),
#  ('o', 'escrito', 'ficaria'),
#  ('escrito', 'ficaria', 'assim'),
#  ('ficaria', 'assim', 'mais'),
#  ('assim', 'mais', 'galante'),
#  ('mais', 'galante', 'e'),
#  ('galante', 'e', 'mais'),
#  ('e', 'mais', 'novo'),
#  ('mais', 'novo', '.'),
#  ('novo', '.', '</s>'),
#  ('<s>', '<s>', 'Moisés'),
#  ('<s>', 'Moisés', ','),
#  ('Moisés', ',', 'que'),
#  (',', 'que', 'também'),
#  ('que', 'também', 'contou'),
#  ('também', 'contou', 'a'),
#  ('contou', 'a', 'sua'),
#  ('a', 'sua', 'morte'),
#  ('sua', 'morte', ','),
#  ('morte', ',', 'não'),
#  (',', 'não', 'a'),
#  ('não', 'a', 'pôs'),
#  ('a', 'pôs', 'no'),
#  ('pôs', 'no', 'intróito'),
#  ('no', 'intróito', ','),
#  ('intróito', ',', 'mas'),
#  (',', 'mas', 'no'),
#  ('mas', 'no', 'cabo'),
#  ('no', 'cabo', ':'),
#  ('cabo', ':', 'diferença'),
#  (':', 'diferença', 'radical'),
#  ('diferença', 'radical', 'entre'),
#  ('radical', 'entre', 'este'),
#  ('entre', 'este', 'livro'),
#  ('este', 'livro', 'e'),
#  ('livro', 'e', 'o'),
#  ('e', 'o', 'Pentateuco'),
#  ('o', 'Pentateuco', '.'),
#  ('Pentateuco', '.', '</s>'),
#  ('<s>', '<s>', 'Dito'),
#  ('<s>', 'Dito', 'isto'),
#  ('Dito', 'isto', ','),
#  ('isto', ',', 'expirei'),
#  (',', 'expirei', 'às'),
#  ('expirei', 'às', 'duas'),
#  ('às', 'duas', 'horas'),
#  ('duas', 'horas', 'da'),
#  ('horas', 'da', 'tarde'),
#  ('da', 'tarde', 'de'),
#  ('tarde', 'de', 'uma'),
#  ('de', 'uma', 'sexta'),
#  ('uma', 'sexta', '-'),
#  ('sexta', '-', 'feira'),
#  ('-', 'feira', 'do'),
#  ('feira', 'do', 'mês'),
#  ('do', 'mês', 'de'),
#  ('mês', 'de', 'agosto'),
#  ('de', 'agosto', 'de'),
#  ('agosto', 'de', '1869'),
#  ('de', '1869', ','),
#  ('1869', ',', 'na'),
#  (',', 'na', 'minha'),
#  ('na', 'minha', 'bela'),
#  ('minha', 'bela', 'chácara'),
#  ('bela', 'chácara', 'de'),
#  ('chácara', 'de', 'Catumbi'),
#  ('de', 'Catumbi', '.'),
#  ('Catumbi', '.', '</s>'),
#  ('<s>', '<s>', 'Tinha'),
#  ('<s>', 'Tinha', 'uns'),
#  ('Tinha', 'uns', 'sessenta'),
#  ('uns', 'sessenta', 'e'),
#  ('sessenta', 'e', 'quatro'),
#  ('e', 'quatro', 'anos'),
#  ('quatro', 'anos', ','),
#  ('anos', ',', 'rijos'),
#  (',', 'rijos', 'e'),
#  ('rijos', 'e', 'prósperos'),
#  ('e', 'prósperos', ','),
#  ('prósperos', ',', 'era'),
#  (',', 'era', 'solteiro'),
#  ('era', 'solteiro', ','),
#  ('solteiro', ',', 'possuía'),
#  (',', 'possuía', 'cerca'),
#  ('possuía', 'cerca', 'de'),
#  ('cerca', 'de', 'trezentos'),
#  ('de', 'trezentos', 'contos'),
#  ('trezentos', 'contos', 'e'),
#  ('contos', 'e', 'fui'),
#  ('e', 'fui', 'acompanhado'),
#  ('fui', 'acompanhado', 'ao'),
#  ('acompanhado', 'ao', 'cemitério'),
#  ('ao', 'cemitério', 'por'),
#  ('cemitério', 'por', 'onze'),
#  ('por', 'onze', 'amigos'),
#  ('onze', 'amigos', '.'),
#  ('amigos', '.', '</s>'),
#  ('<s>', '<s>', 'Onze'),
#  ('<s>', 'Onze', 'amigos'),
#  ('Onze', 'amigos', '!'),
#  ('amigos', '!', '</s>'),
#  ('!', '</s>', '<s>'),
#  ('<s>', '<s>', 'Verdade'),
#  ('<s>', 'Verdade', 'é'),
#  ('Verdade', 'é', 'que'),
#  ('é', 'que', 'não'),
#  ('que', 'não', 'houve'),
#  ('não', 'houve', 'cartas'),
#  ('houve', 'cartas', 'nem'),
#  ('cartas', 'nem', 'anúncios'),
#  ('nem', 'anúncios', '.'),
#  ('anúncios', '.', '</s>'),
#  ('Acresce', 'que', 'chovia'),
#  ('que', 'chovia', '\x97'),
#  ('chovia', '\x97', 'peneirava'),
#  ('\x97', 'peneirava', 'uma'),
#  ('peneirava', 'uma', 'chuvinha'),
#  ('uma', 'chuvinha', 'miúda'),
#  ('chuvinha', 'miúda', ','),
#  ('miúda', ',', 'triste'),
#  (',', 'triste', 'e'),
#  ('triste', 'e', 'constante'),
#  ('e', 'constante', ','),
#  ('constante', ',', 'tão'),
#  (',', 'tão', 'constante'),
#  ('tão', 'constante', 'e'),
#  ('constante', 'e', 'tão'),
#  ('e', 'tão', 'triste'),
#  ('tão', 'triste', ','),
#  ('triste', ',', 'que'),
#  (',', 'que', 'levou'),
#  ('que', 'levou', 'um'),
#  ('levou', 'um', 'daqueles'),
#  ('um', 'daqueles', 'fiéis'),
#  ('daqueles', 'fiéis', 'da'),
#  ('fiéis', 'da', 'última'),
#  ('da', 'última', 'hora'),
#  ('última', 'hora', 'a'),
#  ('hora', 'a', 'intercalar'),
#  ('a', 'intercalar', 'esta'),
#  ('intercalar', 'esta', 'engenhosa'),
#  ('esta', 'engenhosa', 'idéia'),
#  ('engenhosa', 'idéia', 'no'),
#  ('idéia', 'no', 'discurso'),
#  ('no', 'discurso', 'que'),
#  ('discurso', 'que', 'proferiu'),
#  ('que', 'proferiu', 'à'),
#  ('proferiu', 'à', 'beira'),
#  ('à', 'beira', 'de'),
#  ('beira', 'de', 'minha'),
#  ('de', 'minha', 'cova'),
#  ('minha', 'cova', ':'),
#  ('cova', ':', '\x97'),
#  (':', '\x97', '\x93'),
#  ('\x97', '\x93', 'Vós'),
#  ('\x93', 'Vós', ','),
#  ('Vós', ',', 'que'),
#  (',', 'que', 'o'),
#  ('que', 'o', 'conhecestes'),
#  ('o', 'conhecestes', ','),
#  ('conhecestes', ',', 'meus'),
#  (',', 'meus', 'senhores'),
#  ('meus', 'senhores', ','),
#  ('senhores', ',', 'vós'),
#  (',', 'vós', 'podeis'),
#  ('vós', 'podeis', 'dizer'),
#  ('podeis', 'dizer', 'comigo'),
#  ('dizer', 'comigo', 'que'),
#  ('comigo', 'que', 'a'),
#  ('que', 'a', 'natureza'),
#  ('a', 'natureza', 'parece'),
#  ('natureza', 'parece', 'estar'),
#  ('parece', 'estar', 'chorando'),
#  ('estar', 'chorando', 'a'),
#  ('chorando', 'a', 'perda'),
#  ('a', 'perda', 'irreparável'),
#  ('perda', 'irreparável', 'de'),
#  ('irreparável', 'de', 'um'),
#  ('de', 'um', 'dos'),
#  ('um', 'dos', 'mais'),
#  ('dos', 'mais', 'belos'),
#  ('mais', 'belos', 'caracteres'),
#  ('belos', 'caracteres', 'que'),
#  ('caracteres', 'que', 'têm'),
#  ('que', 'têm', 'honrado'),
#  ('têm', 'honrado', 'a'),
#  ('honrado', 'a', 'humanidade'),
#  ('a', 'humanidade', '.'),
#  ('humanidade', '.', '</s>'),
#  ('<s>', '<s>', 'Este'),
#  ('<s>', 'Este', 'ar'),
#  ('Este', 'ar', 'sombrio'),
#  ('ar', 'sombrio', ','),
#  ('sombrio', ',', 'estas'),
#  (',', 'estas', 'gotas'),
#  ...]

# %% [markdown]
# Para o cálculo da frequência relativa de trigramas, precisamos, para cada trigrama, pegar o bigrama formado pelas primeiras duas palavras do trigrama. Assim, calculamos a probabilidade da última palavra do trigrama surgir no corpus, dado a aparição das duas primeiras palavras no trigrama:
#
# <center>$P(w_{3} | w_{1},w_{2}) = \frac{c(w_{1}, w_{2}, w_{3})}{c(w_{1}, w_{2})}$</center>
#
# Assim, para cada trigrama único, pegamos o bigrama correspondente e calculamos a probabilidade acima. Vamos colocar todos esses dados em um dataframe pandas, por isso, vamos criar listas com os bigramas correspondentes para cada trigrama (primeira e segunda palavra no trigrama) e a última palavra do trigrama, formando uma tabela.

# %%
list_bigram = []
list_lastword = []
list_probs = []

for t in trigram_key:
    key_bigram = (t[0], t[1])
    prob = count_trigram[t] / count_bigram[key_bigram]
    list_bigram.append(key_bigram)
    list_lastword.append(t[2])
    list_probs.append(prob)

# %% [markdown]
# A partir das listas criadas acima, vamos criar um dataframe pandas. Esse dataframe será nosso modelo linguístico.

# %%
model_df = pd.DataFrame({'bigram': list_bigram, 'lastword': list_lastword, 'prob': list_probs})
model_df
# Out:
#                        bigram    lastword      prob
# 0                  (<s>, <s>)     Romance  0.000262
# 1              (<s>, Romance)           ,  1.000000
# 2                (Romance, ,)    Memórias  1.000000
# 3               (,, Memórias)    Póstumas  1.000000
# 4        (Memórias, Póstumas)          de  0.800000
# 5              (Póstumas, de)        Brás  1.000000
# 6                  (de, Brás)       Cubas  0.833333
# 7               (Brás, Cubas)           ,  0.482759
# 8                  (Cubas, ,)        1880  0.062500
# 9                   (,, 1880)        </s>  1.000000
# 10               (1880, </s>)         <s>  1.000000
# 11                (</s>, <s>)         <s>  1.000000
# 12                 (<s>, <s>)    Memórias  0.000262
# 13            (<s>, Memórias)    Póstumas  1.000000
# 14              (Brás, Cubas)        </s>  0.034483
# 15              (Cubas, </s>)         <s>  1.000000
# 16                 (<s>, <s>)       Texto  0.000262
# 17               (<s>, Texto)           -  1.000000
# 18                 (Texto, -)       fonte  1.000000
# 19                 (-, fonte)           :  1.000000
# 20                 (fonte, :)        Obra  1.000000
# 21                  (:, Obra)    Completa  1.000000
# 22           (Obra, Completa)           ,  1.000000
# 23              (Completa, ,)     Machado  1.000000
# 24               (,, Machado)          de  1.000000
# 25              (Machado, de)       Assis  1.000000
# 26                (de, Assis)           ,  0.500000
# 27                 (Assis, ,)         Rio  1.000000
# 28                   (,, Rio)          de  1.000000
# 29                  (Rio, de)     Janeiro  1.000000
# ...                       ...         ...       ...
# 66437              (achei, -)          me  0.111111
# 66438               (com, um)     pequeno  0.020000
# 66439           (um, pequeno)       saldo  1.000000
# 66440        (pequeno, saldo)           ,  1.000000
# 66441              (saldo, ,)         que  1.000000
# 66442                  (é, a)  derradeira  0.026316
# 66443         (a, derradeira)    negativa  1.000000
# 66444  (derradeira, negativa)       deste  1.000000
# 66445       (negativa, deste)    capítulo  1.000000
# 66446       (deste, capítulo)          de  1.000000
# 66447          (capítulo, de)   negativas  0.500000
# 66448         (de, negativas)           :  0.500000
# 66449          (negativas, :)             1.000000
# 66450                  (:, )         Não  0.031250
# 66451                (, Não)        tive  0.016393
# 66452             (Não, tive)      filhos  0.500000
# 66453          (tive, filhos)           ,  1.000000
# 66454             (filhos, ,)         não  0.250000
# 66455                (,, não)   transmiti  0.005682
# 66456        (não, transmiti)           a  1.000000
# 66457          (transmiti, a)     nenhuma  1.000000
# 66458            (a, nenhuma)    criatura  1.000000
# 66459     (nenhuma, criatura)           o  1.000000
# 66460           (criatura, o)      legado  1.000000
# 66461             (o, legado)          da  1.000000
# 66462            (legado, da)       nossa  1.000000
# 66463             (da, nossa)     miséria  0.071429
# 66464        (nossa, miséria)           .  1.000000
# 66465              (<s>, <s>)         FIM  0.000262
# 66466              (<s>, FIM)        </s>  1.000000
#
# [66467 rows x 3 columns]

# %% [markdown]
# Vamos testar nosso dataframe. Crie um dataframe contendo apenas o bigrama ('Brás', 'Cubas').

# %%
bigram_df = model_df.loc[model_df['bigram'] == ('Brás', 'Cubas')]
bigram_df
# Out:
#               bigram lastword      prob
# 7      (Brás, Cubas)        ,  0.482759
# 14     (Brás, Cubas)     </s>  0.034483
# 92     (Brás, Cubas)      foi  0.034483
# 179    (Brás, Cubas)      são  0.034483
# 211    (Brás, Cubas)        (  0.034483
# 320    (Brás, Cubas)       se  0.034483
# 338    (Brás, Cubas)       um  0.034483
# 716    (Brás, Cubas)        .  0.206897
# 27329  (Brás, Cubas)        ;  0.068966
# 39094  (Brás, Cubas)      não  0.034483

# %% [markdown]
# Agora mostre que temos um modelo probabilístico. Para que um modelo seja probabilístico, precisamos que todas as probablidades de um dado bigrama somem 1. Complete a linha abaixo somando as probabilidades do dataframe criado acima. A soma deve ser aproximadamente 1.

# %%
calc_prob = sum(bigram_df['prob'])
calc_prob
# Out:
# 0.9999999999999998

# %% [markdown]
# Com o nosso modelo criado, vamos usá-lo para gerar texto. Para gerar texto temos que iniciar com o bigrama de início de sentença, pegar todos os trigramas que iniciam com esse bigrama e tomar a próxima palavra de acordo com sua probabilidade. O próximo bigrama será as duas últimas palavras do trigrama escolhido, isto é, pego a última palavra do bigrama atual e junto com a próxima palavra escolhida de acordo com a probabilidade. Complete o código abaixo para gerar o texto.

# %%
num_sents = 50
current_bigram = ('<s>', '<s>')
i = 0
while i < num_sents:
    df = model_df.loc[model_df['bigram'] == current_bigram]
    words = df['lastword'].values
    probs = df['prob'].values
    last_word = random.choices(words, probs)[0]
    
    current_bigram = (current_bigram[1], last_word)
    
    if last_word == '</s>':
        i+=1
    
    if last_word != '<s>' and last_word != '</s>':
        print(last_word, end=' ')
# Out:
#  Que você quis casar com Iaiá , que deviam ser tão seculares como eles . O barão dizia ontem , como era de boca ou do centro , e achou meio de fechar o livro do poeta , por inquietas , por todos os elementos de uma obra difusa , na manhã seguinte , 1806 ; batizei - me a aceitar o diploma era uma espécie de lei da equivalência das janelas , e moveu a cabeça nas mãos , disse - me : Era preciso arejar a consciência e resguardar o decoro . Sentia - me e fechou - se ficar a olhar para as andorinhas . Esta é a minha nomeação à do Lobo Neves , que me disseram depois . Indaguei de Virgília , calada , fazia - me do espírito os pensamentos maus ; preferi dormir , que valia mais , é sacudi - lo . Saí desatinado ; gastei duas mortais horas em vaguear pelos bairros mais excêntricos e desertos , onde eu ficava irresoluto e inquieto , desejoso de a obter não pertence ao faquir somente : é teu orgulho ; mas era tarde ; a expansiva , mais depressa serias deputado . Vamos ao terraço ? Pobre Romualdo ! Não podia sacudir dos olhos a uma das tranças . Após alguns instantes para o outro , sem padecer um forte acesso , tornava ao plano da casa , havia certa lógica , certa graça indolente . Não , não tenho outra lei . Et coetera . BRÁS CUBAS ..............................................! Fui ; Virgília foi o quê ? Lá iremos . Minha mãe era morta , nem indigno dos benefícios da Providência ; e , porque o cancro é indiferente às virtudes do sujeito ; finalmente , o homem mais probo que conheci a família de Iaiá ! A esperança de que ele me soprava por achar - me uma reflexão imoral que eu , que não queria entregar a casa de homem roubado . Se eu ao boleeiro . D . Plácida , talvez as pirâmides do Egito , talvez fosse para o outro . Se possuísse os aparelhos próprios , incluía neste livro é enfadonho , cheira a sepulcro , lhe restituíra a consciência se acomoda , a facada anônima , a princípio que o prazer de as comparar e o vinho da miséria .  Não fale nisso ! A dureza da interrupção , tratando - se uma convicção de superioridade sobre uma multidão de outras mulheres menos bonitas ou absolutamente feias ? Fui ; mas cumpre advertir que a moral possa arejar continuamente a consciência se acomoda , a disfarçar os rasgões e os fâmulos , que não houve cartas nem anúncios . Aquilo sim ! Eu só pensava naquele embrião anônimo , de pouco cérebro e muito calção . Virgília tinha alguma coisa , que ela vira num joalheiro , retorquiu - me com alvoroço ; declarou - me que falamos muito , disse . Era ele . Somadas umas coisas e outras , o mais medroso dos beijos . todos os olhos de cima ; chamava - me padecer todos os seus livros . indiscreta ! Não eram remorsos . Lá o deixei ; meti - as o lascivo . Se ele estiver em casa , quando seria ele ministro . Por exemplo , sendo , porém , o céu tranqüilo e constante , como os pontinhos e vírgulas escuras percorrem o campo visual dos olhos bonitos , e naquela manhã parece que gostava de semelhante idéia . exclamou a boa dama sacou um pedaço de pau .  Sua mana ? Que digo ? Multidão , cujo amor cobicei até à porta , etc . Ah ! E essas palavras ressoavam - me notar que ele imaginou as trezentas cubas aos mouros . Eis uma combinação assaz complexa e vaga , e não perde uma presidência de província ? CAPÍTULO XC / O ENFERMO Éramos tão amigos ! Marcela ofereceu - lhe um movimento duplo de rotação , concluía Lobo Neves e eu entenderei o que pouco antes me dera agora o leitor , entretanto , chamou um escravo para me servir o doce  por pirraça ; e verdadeiramente não era indigno das cogitações de um ou de flor a flor amarela , estigmada pelo mesmo flagelo , que lhe replicasse . Tinham - me que a filha , casada com o filho e trazia - lhe ingenuamente que não ; não queiras que o empacha , e adivinhais , portanto , é positivo . Com efeito , um emplastro anti - hipocondríaco , destinado a aliviar a nossa salvação . Quando dei por abalado : levei - os pelo buraco da fechadura . Enquanto esta palavra , uma das sensações mais sutis desse  ...

# %% [markdown]
# Agora é a sua vez! Vamos criar um modelo mais performático para o corpus. Para isso, vamos usar 5-gramas. Usando a função ngrams, crie um modelo de 5-gramas e gere texto a partir dele.
#
# Lembre-se que precisamos do seguinte para criar o modelo:
#
# * Inserir tokens de inicio e fim de sentença adequados ao modelo, isto é, 4 tokens no início da sentença
# * Criar listas de 4-gramas e 5-gramas usando o ngrams
# * Contar os ngramas de cada lista
# * Calcular a probabilidade adequadamente
# * Criar o modelo em forma de dataframe
# * Usar o modelo para gerar texto
#
# Use o código acima como exemplo e crie o seu próprio modelo.

# %%
corpus = machado.sents('romance/marm05.txt')
corpus[0]#essa é uma sentença
# Out:
# ['Romance', ',', 'Memórias', 'Póstumas', 'de', 'Brás', 'Cubas', ',', '1880']

# %% [markdown]
# Inserir token de início e fim de sentença com 5-gramas

# %%
words = []
for sent in corpus:
    sent.insert(0, '<s>')#insere token no início da sentença
    sent.insert(0, '<s>')#insere token no início da sentença
    sent.insert(0, '<s>')#insere token no início da sentença
    sent.insert(0, '<s>')#insere token no início da sentença
    sent.append('</s>')
    words.extend(sent)

# %%
words[:9]
# Out:
# ['<s>', '<s>', '<s>', '<s>', 'Romance', ',', 'Memórias', 'Póstumas', 'de']

# %% [markdown]
# Criar lista de 4 e 5-gramas

# %%
words_fourgram = ngrams(words,4)
words_fivegram = ngrams(words,5)

# %%
words_fourgram
# Out:
# <generator object ngrams at 0x000001FDB24EC390>

# %% [markdown]
# Contar o ngrams de cada lista

# %%
count_fourgram = Counter(words_fourgram)
count_fivegram = Counter(words_fivegram)

# %%
count_fourgram
# Out:
# Counter({('<s>', '<s>', '<s>', '<s>'): 3822,
#          ('<s>', '<s>', '<s>', 'Romance'): 1,
#          ('<s>', '<s>', 'Romance', ','): 1,
#          ('<s>', 'Romance', ',', 'Memórias'): 1,
#          ('Romance', ',', 'Memórias', 'Póstumas'): 1,
#          (',', 'Memórias', 'Póstumas', 'de'): 1,
#          ('Memórias', 'Póstumas', 'de', 'Brás'): 4,
#          ('Póstumas', 'de', 'Brás', 'Cubas'): 4,
#          ('de', 'Brás', 'Cubas', ','): 1,
#          ('Brás', 'Cubas', ',', '1880'): 1,
#          ('Cubas', ',', '1880', '</s>'): 1,
#          (',', '1880', '</s>', '<s>'): 1,
#          ('1880', '</s>', '<s>', '<s>'): 1,
#          ('</s>', '<s>', '<s>', '<s>'): 3821,
#          ('<s>', '<s>', '<s>', 'Memórias'): 1,
#          ('<s>', '<s>', 'Memórias', 'Póstumas'): 1,
#          ('<s>', 'Memórias', 'Póstumas', 'de'): 1,
#          ('de', 'Brás', 'Cubas', '</s>'): 1,
#          ('Brás', 'Cubas', '</s>', '<s>'): 1,
#          ('Cubas', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Texto'): 1,
#          ('<s>', '<s>', 'Texto', '-'): 1,
#          ('<s>', 'Texto', '-', 'fonte'): 1,
#          ('Texto', '-', 'fonte', ':'): 1,
#          ('-', 'fonte', ':', 'Obra'): 1,
#          ('fonte', ':', 'Obra', 'Completa'): 1,
#          (':', 'Obra', 'Completa', ','): 1,
#          ('Obra', 'Completa', ',', 'Machado'): 1,
#          ('Completa', ',', 'Machado', 'de'): 1,
#          (',', 'Machado', 'de', 'Assis'): 1,
#          ('Machado', 'de', 'Assis', ','): 1,
#          ('de', 'Assis', ',', 'Rio'): 1,
#          ('Assis', ',', 'Rio', 'de'): 1,
#          (',', 'Rio', 'de', 'Janeiro'): 1,
#          ('Rio', 'de', 'Janeiro', ':'): 1,
#          ('de', 'Janeiro', ':', 'Editora'): 1,
#          ('Janeiro', ':', 'Editora', 'Nova'): 1,
#          (':', 'Editora', 'Nova', 'Aguilar'): 1,
#          ('Editora', 'Nova', 'Aguilar', ','): 1,
#          ('Nova', 'Aguilar', ',', '1994'): 1,
#          ('Aguilar', ',', '1994', '.'): 1,
#          (',', '1994', '.', '</s>'): 1,
#          ('1994', '.', '</s>', '<s>'): 1,
#          ('.', '</s>', '<s>', '<s>'): 2813,
#          ('<s>', '<s>', '<s>', 'Publicado'): 1,
#          ('<s>', '<s>', 'Publicado', 'originalmente'): 1,
#          ('<s>', 'Publicado', 'originalmente', 'em'): 1,
#          ('Publicado', 'originalmente', 'em', 'folhetins'): 1,
#          ('originalmente', 'em', 'folhetins', ','): 1,
#          ('em', 'folhetins', ',', 'a'): 1,
#          ('folhetins', ',', 'a', 'partir'): 1,
#          (',', 'a', 'partir', 'de'): 1,
#          ('a', 'partir', 'de', 'março'): 1,
#          ('partir', 'de', 'março', 'de'): 1,
#          ('de', 'março', 'de', '1880'): 1,
#          ('março', 'de', '1880', ','): 1,
#          ('de', '1880', ',', 'na'): 1,
#          ('1880', ',', 'na', 'Revista'): 1,
#          (',', 'na', 'Revista', 'Brasileira'): 1,
#          ('na', 'Revista', 'Brasileira', '.'): 1,
#          ('Revista', 'Brasileira', '.', '</s>'): 1,
#          ('Brasileira', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Ao'): 33,
#          ('<s>', '<s>', 'Ao', 'verme'): 1,
#          ('<s>', 'Ao', 'verme', 'que'): 1,
#          ('Ao', 'verme', 'que', 'primeiro'): 1,
#          ('verme', 'que', 'primeiro', 'roeu'): 1,
#          ('que', 'primeiro', 'roeu', 'as'): 1,
#          ('primeiro', 'roeu', 'as', 'frias'): 1,
#          ('roeu', 'as', 'frias', 'carnes'): 1,
#          ('as', 'frias', 'carnes', 'do'): 1,
#          ('frias', 'carnes', 'do', 'meu'): 1,
#          ('carnes', 'do', 'meu', 'cadáver'): 1,
#          ('do', 'meu', 'cadáver', '</s>'): 1,
#          ('meu', 'cadáver', '</s>', '<s>'): 1,
#          ('cadáver', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'dedico'): 1,
#          ('<s>', '<s>', 'dedico', 'como'): 1,
#          ('<s>', 'dedico', 'como', 'saudosa'): 1,
#          ('dedico', 'como', 'saudosa', 'lembrança'): 1,
#          ('como', 'saudosa', 'lembrança', '</s>'): 1,
#          ('saudosa', 'lembrança', '</s>', '<s>'): 1,
#          ('lembrança', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'estas'): 1,
#          ('<s>', '<s>', 'estas', 'Memórias'): 1,
#          ('<s>', 'estas', 'Memórias', 'Póstumas'): 1,
#          ('estas', 'Memórias', 'Póstumas', '</s>'): 1,
#          ('Memórias', 'Póstumas', '</s>', '<s>'): 1,
#          ('Póstumas', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Prólogo'): 1,
#          ('<s>', '<s>', 'Prólogo', 'da'): 1,
#          ('<s>', 'Prólogo', 'da', 'terceira'): 1,
#          ('Prólogo', 'da', 'terceira', 'edição'): 1,
#          ('da', 'terceira', 'edição', '</s>'): 1,
#          ('terceira', 'edição', '</s>', '<s>'): 1,
#          ('edição', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'A'): 125,
#          ('<s>', '<s>', 'A', 'primeira'): 2,
#          ('<s>', 'A', 'primeira', 'edição'): 1,
#          ('A', 'primeira', 'edição', 'destas'): 1,
#          ('primeira', 'edição', 'destas', 'Memórias'): 1,
#          ('edição', 'destas', 'Memórias', 'Póstumas'): 1,
#          ('destas', 'Memórias', 'Póstumas', 'de'): 1,
#          ('de', 'Brás', 'Cubas', 'foi'): 1,
#          ('Brás', 'Cubas', 'foi', 'feita'): 1,
#          ('Cubas', 'foi', 'feita', 'aos'): 1,
#          ('foi', 'feita', 'aos', 'pedaços'): 1,
#          ('feita', 'aos', 'pedaços', 'na'): 1,
#          ('aos', 'pedaços', 'na', 'Revista'): 1,
#          ('pedaços', 'na', 'Revista', 'Brasileira'): 1,
#          ('na', 'Revista', 'Brasileira', ','): 1,
#          ('Revista', 'Brasileira', ',', 'pelos'): 1,
#          ('Brasileira', ',', 'pelos', 'anos'): 1,
#          (',', 'pelos', 'anos', 'de'): 1,
#          ('pelos', 'anos', 'de', '1880'): 1,
#          ('anos', 'de', '1880', '.'): 1,
#          ('de', '1880', '.', '</s>'): 1,
#          ('1880', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Postas'): 1,
#          ('<s>', '<s>', 'Postas', 'mais'): 1,
#          ('<s>', 'Postas', 'mais', 'tarde'): 1,
#          ('Postas', 'mais', 'tarde', 'em'): 1,
#          ('mais', 'tarde', 'em', 'livro'): 1,
#          ('tarde', 'em', 'livro', ','): 1,
#          ('em', 'livro', ',', 'corrigi'): 1,
#          ('livro', ',', 'corrigi', 'o'): 1,
#          (',', 'corrigi', 'o', 'texto'): 1,
#          ('corrigi', 'o', 'texto', 'em'): 1,
#          ('o', 'texto', 'em', 'vários'): 1,
#          ('texto', 'em', 'vários', 'lugares'): 1,
#          ('em', 'vários', 'lugares', '.'): 1,
#          ('vários', 'lugares', '.', '</s>'): 1,
#          ('lugares', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Agora'): 18,
#          ('<s>', '<s>', 'Agora', 'que'): 1,
#          ('<s>', 'Agora', 'que', 'tive'): 1,
#          ('Agora', 'que', 'tive', 'de'): 1,
#          ('que', 'tive', 'de', 'o'): 1,
#          ('tive', 'de', 'o', 'rever'): 1,
#          ('de', 'o', 'rever', 'para'): 1,
#          ('o', 'rever', 'para', 'a'): 1,
#          ('rever', 'para', 'a', 'terceira'): 1,
#          ('para', 'a', 'terceira', 'edição'): 1,
#          ('a', 'terceira', 'edição', ','): 1,
#          ('terceira', 'edição', ',', 'emendei'): 1,
#          ('edição', ',', 'emendei', 'ainda'): 1,
#          (',', 'emendei', 'ainda', 'alguma'): 1,
#          ('emendei', 'ainda', 'alguma', 'coisa'): 1,
#          ('ainda', 'alguma', 'coisa', 'e'): 1,
#          ('alguma', 'coisa', 'e', 'suprimi'): 1,
#          ('coisa', 'e', 'suprimi', 'duas'): 1,
#          ('e', 'suprimi', 'duas', 'ou'): 1,
#          ('suprimi', 'duas', 'ou', 'três'): 1,
#          ('duas', 'ou', 'três', 'dúzias'): 1,
#          ('ou', 'três', 'dúzias', 'de'): 1,
#          ('três', 'dúzias', 'de', 'linhas'): 1,
#          ('dúzias', 'de', 'linhas', '.'): 1,
#          ('de', 'linhas', '.', '</s>'): 1,
#          ('linhas', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Assim'): 12,
#          ('<s>', '<s>', 'Assim', 'composta'): 1,
#          ('<s>', 'Assim', 'composta', ','): 1,
#          ('Assim', 'composta', ',', 'sai'): 1,
#          ('composta', ',', 'sai', 'novamente'): 1,
#          (',', 'sai', 'novamente', 'à'): 1,
#          ('sai', 'novamente', 'à', 'luz'): 1,
#          ('novamente', 'à', 'luz', 'esta'): 1,
#          ('à', 'luz', 'esta', 'obra'): 1,
#          ('luz', 'esta', 'obra', 'que'): 1,
#          ('esta', 'obra', 'que', 'alguma'): 1,
#          ('obra', 'que', 'alguma', 'benevolência'): 1,
#          ('que', 'alguma', 'benevolência', 'parece'): 1,
#          ('alguma', 'benevolência', 'parece', 'ter'): 1,
#          ('benevolência', 'parece', 'ter', 'encontrado'): 1,
#          ('parece', 'ter', 'encontrado', 'no'): 1,
#          ('ter', 'encontrado', 'no', 'público'): 1,
#          ('encontrado', 'no', 'público', '.'): 1,
#          ('no', 'público', '.', '</s>'): 1,
#          ('público', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Capistrano'): 1,
#          ('<s>', '<s>', 'Capistrano', 'de'): 1,
#          ('<s>', 'Capistrano', 'de', 'Abreu'): 1,
#          ('Capistrano', 'de', 'Abreu', ','): 1,
#          ('de', 'Abreu', ',', 'noticiando'): 1,
#          ('Abreu', ',', 'noticiando', 'a'): 1,
#          (',', 'noticiando', 'a', 'publicação'): 1,
#          ('noticiando', 'a', 'publicação', 'do'): 1,
#          ('a', 'publicação', 'do', 'livro'): 1,
#          ('publicação', 'do', 'livro', ','): 1,
#          ('do', 'livro', ',', 'perguntava'): 1,
#          ('livro', ',', 'perguntava', ':'): 1,
#          (',', 'perguntava', ':', '\x93'): 1,
#          ('perguntava', ':', '\x93', 'As'): 1,
#          (':', '\x93', 'As', 'Memórias'): 1,
#          ('\x93', 'As', 'Memórias', 'Póstumas'): 1,
#          ('As', 'Memórias', 'Póstumas', 'de'): 1,
#          ('de', 'Brás', 'Cubas', 'são'): 1,
#          ('Brás', 'Cubas', 'são', 'um'): 1,
#          ('Cubas', 'são', 'um', 'romance'): 1,
#          ('são', 'um', 'romance', '?\x94'): 1,
#          ('um', 'romance', '?\x94', 'Macedo'): 1,
#          ('romance', '?\x94', 'Macedo', 'Soares'): 1,
#          ('?\x94', 'Macedo', 'Soares', ','): 1,
#          ('Macedo', 'Soares', ',', 'em'): 1,
#          ('Soares', ',', 'em', 'carta'): 1,
#          (',', 'em', 'carta', 'que'): 1,
#          ('em', 'carta', 'que', 'me'): 1,
#          ('carta', 'que', 'me', 'escreveu'): 1,
#          ('que', 'me', 'escreveu', 'por'): 1,
#          ('me', 'escreveu', 'por', 'esse'): 1,
#          ('escreveu', 'por', 'esse', 'tempo'): 1,
#          ('por', 'esse', 'tempo', ','): 1,
#          ('esse', 'tempo', ',', 'recordava'): 1,
#          ('tempo', ',', 'recordava', 'amigamente'): 1,
#          (',', 'recordava', 'amigamente', 'as'): 1,
#          ('recordava', 'amigamente', 'as', 'Viagens'): 1,
#          ('amigamente', 'as', 'Viagens', 'na'): 1,
#          ('as', 'Viagens', 'na', 'minha'): 1,
#          ('Viagens', 'na', 'minha', 'terra'): 1,
#          ('na', 'minha', 'terra', '.'): 1,
#          ('minha', 'terra', '.', '</s>'): 1,
#          ('terra', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', 'Ao', 'primeiro'): 1,
#          ('<s>', 'Ao', 'primeiro', 'respondia'): 1,
#          ('Ao', 'primeiro', 'respondia', 'já'): 1,
#          ('primeiro', 'respondia', 'já', 'o'): 1,
#          ('respondia', 'já', 'o', 'defunto'): 1,
#          ('já', 'o', 'defunto', 'Brás'): 1,
#          ('o', 'defunto', 'Brás', 'Cubas'): 1,
#          ('defunto', 'Brás', 'Cubas', '('): 1,
#          ('Brás', 'Cubas', '(', 'como'): 1,
#          ('Cubas', '(', 'como', 'o'): 1,
#          ('(', 'como', 'o', 'leitor'): 1,
#          ('como', 'o', 'leitor', 'viu'): 1,
#          ('o', 'leitor', 'viu', 'e'): 1,
#          ('leitor', 'viu', 'e', 'verá'): 1,
#          ('viu', 'e', 'verá', 'no'): 1,
#          ('e', 'verá', 'no', 'prólogo'): 1,
#          ('verá', 'no', 'prólogo', 'dele'): 1,
#          ('no', 'prólogo', 'dele', 'que'): 1,
#          ('prólogo', 'dele', 'que', 'vai'): 1,
#          ('dele', 'que', 'vai', 'adiante'): 1,
#          ('que', 'vai', 'adiante', ')'): 1,
#          ('vai', 'adiante', ')', 'que'): 1,
#          ('adiante', ')', 'que', 'sim'): 1,
#          (')', 'que', 'sim', 'e'): 1,
#          ('que', 'sim', 'e', 'que'): 1,
#          ('sim', 'e', 'que', 'não'): 1,
#          ('e', 'que', 'não', ','): 1,
#          ('que', 'não', ',', 'que'): 2,
#          ('não', ',', 'que', 'era'): 1,
#          (',', 'que', 'era', 'romance'): 1,
#          ('que', 'era', 'romance', 'para'): 1,
#          ('era', 'romance', 'para', 'uns'): 1,
#          ('romance', 'para', 'uns', 'e'): 1,
#          ('para', 'uns', 'e', 'não'): 1,
#          ('uns', 'e', 'não', 'o'): 1,
#          ('e', 'não', 'o', 'era'): 1,
#          ('não', 'o', 'era', 'para'): 1,
#          ('o', 'era', 'para', 'outros'): 1,
#          ('era', 'para', 'outros', '.'): 1,
#          ('para', 'outros', '.', '</s>'): 1,
#          ('outros', '.', '</s>', '<s>'): 10,
#          ('<s>', '<s>', '<s>', 'Quanto'): 16,
#          ('<s>', '<s>', 'Quanto', 'ao'): 4,
#          ('<s>', 'Quanto', 'ao', 'segundo'): 1,
#          ('Quanto', 'ao', 'segundo', ','): 1,
#          ('ao', 'segundo', ',', 'assim'): 1,
#          ('segundo', ',', 'assim', 'se'): 1,
#          (',', 'assim', 'se', 'explicou'): 1,
#          ('assim', 'se', 'explicou', 'o'): 1,
#          ('se', 'explicou', 'o', 'finado'): 1,
#          ('explicou', 'o', 'finado', ':'): 1,
#          ('o', 'finado', ':', '\x93'): 1,
#          ('finado', ':', '\x93', 'Trata'): 1,
#          (':', '\x93', 'Trata', '-'): 1,
#          ('\x93', 'Trata', '-', 'se'): 1,
#          ('Trata', '-', 'se', 'de'): 1,
#          ('-', 'se', 'de', 'uma'): 1,
#          ('se', 'de', 'uma', 'obra'): 1,
#          ('de', 'uma', 'obra', 'difusa'): 2,
#          ('uma', 'obra', 'difusa', ','): 2,
#          ('obra', 'difusa', ',', 'na'): 2,
#          ('difusa', ',', 'na', 'qual'): 2,
#          (',', 'na', 'qual', 'eu'): 2,
#          ('na', 'qual', 'eu', ','): 2,
#          ('qual', 'eu', ',', 'Brás'): 2,
#          ('eu', ',', 'Brás', 'Cubas'): 3,
#          (',', 'Brás', 'Cubas', ','): 4,
#          ('Brás', 'Cubas', ',', 'se'): 2,
#          ('Cubas', ',', 'se', 'adotei'): 2,
#          (',', 'se', 'adotei', 'a'): 2,
#          ('se', 'adotei', 'a', 'forma'): 2,
#          ('adotei', 'a', 'forma', 'livre'): 2,
#          ('a', 'forma', 'livre', 'de'): 2,
#          ('forma', 'livre', 'de', 'um'): 2,
#          ('livre', 'de', 'um', 'Sterne'): 2,
#          ('de', 'um', 'Sterne', 'ou'): 1,
#          ('um', 'Sterne', 'ou', 'de'): 1,
#          ('Sterne', 'ou', 'de', 'um'): 1,
#          ('ou', 'de', 'um', 'Xavier'): 2,
#          ('de', 'um', 'Xavier', 'de'): 2,
#          ('um', 'Xavier', 'de', 'Maistre'): 2,
#          ('Xavier', 'de', 'Maistre', ','): 2,
#          ('de', 'Maistre', ',', 'não'): 2,
#          ('Maistre', ',', 'não', 'sei'): 2,
#          (',', 'não', 'sei', 'se'): 8,
#          ('não', 'sei', 'se', 'lhe'): 2,
#          ('sei', 'se', 'lhe', 'meti'): 2,
#          ('se', 'lhe', 'meti', 'algumas'): 2,
#          ('lhe', 'meti', 'algumas', 'rabugens'): 2,
#          ('meti', 'algumas', 'rabugens', 'de'): 2,
#          ('algumas', 'rabugens', 'de', 'pessimismo'): 2,
#          ('rabugens', 'de', 'pessimismo', '.\x94'): 1,
#          ('de', 'pessimismo', '.\x94', 'Toda'): 1,
#          ('pessimismo', '.\x94', 'Toda', 'essa'): 1,
#          ('.\x94', 'Toda', 'essa', 'gente'): 1,
#          ('Toda', 'essa', 'gente', 'viajou'): 1,
#          ('essa', 'gente', 'viajou', ':'): 1,
#          ('gente', 'viajou', ':', 'Xavier'): 1,
#          ('viajou', ':', 'Xavier', 'de'): 1,
#          (':', 'Xavier', 'de', 'Maistre'): 1,
#          ('Xavier', 'de', 'Maistre', 'à'): 1,
#          ('de', 'Maistre', 'à', 'roda'): 1,
#          ('Maistre', 'à', 'roda', 'do'): 1,
#          ('à', 'roda', 'do', 'quarto'): 1,
#          ('roda', 'do', 'quarto', ','): 1,
#          ('do', 'quarto', ',', 'Garret'): 1,
#          ('quarto', ',', 'Garret', 'na'): 1,
#          (',', 'Garret', 'na', 'terra'): 1,
#          ('Garret', 'na', 'terra', 'dele'): 1,
#          ('na', 'terra', 'dele', ','): 1,
#          ('terra', 'dele', ',', 'Sterne'): 1,
#          ('dele', ',', 'Sterne', 'na'): 1,
#          (',', 'Sterne', 'na', 'terra'): 1,
#          ('Sterne', 'na', 'terra', 'dos'): 1,
#          ('na', 'terra', 'dos', 'outros'): 1,
#          ('terra', 'dos', 'outros', '.'): 1,
#          ('dos', 'outros', '.', '</s>'): 4,
#          ('<s>', '<s>', '<s>', 'De'): 31,
#          ('<s>', '<s>', 'De', 'Brás'): 1,
#          ('<s>', 'De', 'Brás', 'Cubas'): 1,
#          ('De', 'Brás', 'Cubas', 'se'): 1,
#          ('Brás', 'Cubas', 'se', 'pode'): 1,
#          ('Cubas', 'se', 'pode', 'dizer'): 1,
#          ('se', 'pode', 'dizer', 'que'): 1,
#          ('pode', 'dizer', 'que', 'viajou'): 1,
#          ('dizer', 'que', 'viajou', 'à'): 1,
#          ('que', 'viajou', 'à', 'roda'): 1,
#          ('viajou', 'à', 'roda', 'da'): 1,
#          ('à', 'roda', 'da', 'vida'): 1,
#          ('roda', 'da', 'vida', '.'): 1,
#          ('da', 'vida', '.', '</s>'): 4,
#          ('vida', '.', '</s>', '<s>'): 12,
#          ('<s>', '<s>', '<s>', 'O'): 110,
#          ('<s>', '<s>', 'O', 'que'): 14,
#          ('<s>', 'O', 'que', 'faz'): 1,
#          ('O', 'que', 'faz', 'do'): 1,
#          ('que', 'faz', 'do', 'meu'): 1,
#          ('faz', 'do', 'meu', 'Brás'): 1,
#          ('do', 'meu', 'Brás', 'Cubas'): 1,
#          ('meu', 'Brás', 'Cubas', 'um'): 1,
#          ('Brás', 'Cubas', 'um', 'autor'): 1,
#          ('Cubas', 'um', 'autor', 'particular'): 1,
#          ('um', 'autor', 'particular', 'é'): 1,
#          ('autor', 'particular', 'é', 'o'): 1,
#          ('particular', 'é', 'o', 'que'): 1,
#          ('é', 'o', 'que', 'ele'): 2,
#          ('o', 'que', 'ele', 'chama'): 1,
#          ('que', 'ele', 'chama', '\x93'): 1,
#          ('ele', 'chama', '\x93', 'rabugens'): 1,
#          ('chama', '\x93', 'rabugens', 'de'): 1,
#          ('\x93', 'rabugens', 'de', 'pessimismo'): 1,
#          ('rabugens', 'de', 'pessimismo', '\x94.'): 1,
#          ('de', 'pessimismo', '\x94.', '</s>'): 1,
#          ('pessimismo', '\x94.', '</s>', '<s>'): 1,
#          ('\x94.', '</s>', '<s>', '<s>'): 12,
#          ('<s>', '<s>', '<s>', 'Há'): 9,
#          ('<s>', '<s>', 'Há', 'na'): 1,
#          ('<s>', 'Há', 'na', 'alma'): 1,
#          ('Há', 'na', 'alma', 'deste'): 1,
#          ('na', 'alma', 'deste', 'livro'): 1,
#          ('alma', 'deste', 'livro', ','): 1,
#          ('deste', 'livro', ',', 'por'): 1,
#          ('livro', ',', 'por', 'mais'): 1,
#          (',', 'por', 'mais', 'risonho'): 1,
#          ('por', 'mais', 'risonho', 'que'): 1,
#          ('mais', 'risonho', 'que', 'pareça'): 1,
#          ('risonho', 'que', 'pareça', ','): 1,
#          ('que', 'pareça', ',', 'um'): 1,
#          ('pareça', ',', 'um', 'sentimento'): 1,
#          (',', 'um', 'sentimento', 'amargo'): 1,
#          ('um', 'sentimento', 'amargo', 'e'): 1,
#          ('sentimento', 'amargo', 'e', 'áspero'): 1,
#          ('amargo', 'e', 'áspero', ','): 1,
#          ('e', 'áspero', ',', 'que'): 1,
#          ('áspero', ',', 'que', 'está'): 1,
#          (',', 'que', 'está', 'longe'): 1,
#          ('que', 'está', 'longe', 'de'): 1,
#          ('está', 'longe', 'de', 'vir'): 1,
#          ('longe', 'de', 'vir', 'de'): 1,
#          ('de', 'vir', 'de', 'seus'): 1,
#          ('vir', 'de', 'seus', 'modelos'): 1,
#          ('de', 'seus', 'modelos', '.'): 1,
#          ('seus', 'modelos', '.', '</s>'): 1,
#          ('modelos', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'É'): 17,
#          ('<s>', '<s>', 'É', 'taça'): 1,
#          ('<s>', 'É', 'taça', 'que'): 1,
#          ('É', 'taça', 'que', 'pode'): 1,
#          ('taça', 'que', 'pode', 'ter'): 1,
#          ('que', 'pode', 'ter', 'lavores'): 1,
#          ('pode', 'ter', 'lavores', 'de'): 1,
#          ('ter', 'lavores', 'de', 'igual'): 1,
#          ('lavores', 'de', 'igual', 'escola'): 1,
#          ('de', 'igual', 'escola', ','): 1,
#          ('igual', 'escola', ',', 'mas'): 1,
#          ('escola', ',', 'mas', 'leva'): 1,
#          (',', 'mas', 'leva', 'outro'): 1,
#          ('mas', 'leva', 'outro', 'vinho'): 1,
#          ('leva', 'outro', 'vinho', '.'): 1,
#          ('outro', 'vinho', '.', '</s>'): 1,
#          ('vinho', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Não'): 185,
#          ('<s>', '<s>', 'Não', 'digo'): 10,
#          ('<s>', 'Não', 'digo', 'mais'): 2,
#          ('Não', 'digo', 'mais', 'para'): 1,
#          ('digo', 'mais', 'para', 'não'): 1,
#          ('mais', 'para', 'não', 'entrar'): 1,
#          ('para', 'não', 'entrar', 'na'): 1,
#          ('não', 'entrar', 'na', 'crítica'): 1,
#          ('entrar', 'na', 'crítica', 'de'): 1,
#          ('na', 'crítica', 'de', 'um'): 1,
#          ('crítica', 'de', 'um', 'defunto'): 1,
#          ('de', 'um', 'defunto', ','): 1,
#          ('um', 'defunto', ',', 'que'): 1,
#          ('defunto', ',', 'que', 'se'): 1,
#          (',', 'que', 'se', 'pintou'): 1,
#          ('que', 'se', 'pintou', 'a'): 1,
#          ('se', 'pintou', 'a', 'si'): 1,
#          ('pintou', 'a', 'si', 'e'): 1,
#          ('a', 'si', 'e', 'a'): 1,
#          ('si', 'e', 'a', 'outros'): 1,
#          ('e', 'a', 'outros', ','): 1,
#          ('a', 'outros', ',', 'conforme'): 1,
#          ('outros', ',', 'conforme', 'lhe'): 1,
#          (',', 'conforme', 'lhe', 'pareceu'): 1,
#          ('conforme', 'lhe', 'pareceu', 'melhor'): 1,
#          ('lhe', 'pareceu', 'melhor', 'e'): 1,
#          ('pareceu', 'melhor', 'e', 'mais'): 1,
#          ('melhor', 'e', 'mais', 'certo'): 1,
#          ('e', 'mais', 'certo', '.'): 1,
#          ('mais', 'certo', '.', '</s>'): 1,
#          ('certo', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Machado'): 1,
#          ('<s>', '<s>', 'Machado', 'de'): 1,
#          ('<s>', 'Machado', 'de', 'Assis'): 1,
#          ('Machado', 'de', 'Assis', '.'): 1,
#          ('de', 'Assis', '.', '</s>'): 1,
#          ('Assis', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'AO'): 1,
#          ('<s>', '<s>', 'AO', 'LEITOR'): 1,
#          ('<s>', 'AO', 'LEITOR', '</s>'): 1,
#          ('AO', 'LEITOR', '</s>', '<s>'): 1,
#          ('LEITOR', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Que'): 39,
#          ('<s>', '<s>', 'Que', 'Stendhal'): 1,
#          ('<s>', 'Que', 'Stendhal', 'confessasse'): 1,
#          ('Que', 'Stendhal', 'confessasse', 'haver'): 1,
#          ('Stendhal', 'confessasse', 'haver', 'escrito'): 1,
#          ('confessasse', 'haver', 'escrito', 'um'): 1,
#          ('haver', 'escrito', 'um', 'de'): 1,
#          ('escrito', 'um', 'de', 'seus'): 1,
#          ('um', 'de', 'seus', 'livros'): 1,
#          ('de', 'seus', 'livros', 'para'): 1,
#          ('seus', 'livros', 'para', 'cem'): 1,
#          ('livros', 'para', 'cem', 'leitores'): 1,
#          ('para', 'cem', 'leitores', ','): 1,
#          ('cem', 'leitores', ',', 'coisa'): 1,
#          ('leitores', ',', 'coisa', 'é'): 1,
#          (',', 'coisa', 'é', 'que'): 1,
#          ('coisa', 'é', 'que', 'admira'): 1,
#          ('é', 'que', 'admira', 'e'): 1,
#          ('que', 'admira', 'e', 'consterna'): 1,
#          ('admira', 'e', 'consterna', '.'): 1,
#          ('e', 'consterna', '.', '</s>'): 1,
#          ('consterna', '.', '</s>', '<s>'): 1,
#          ('<s>', 'O', 'que', 'não'): 2,
#          ('O', 'que', 'não', 'admira'): 1,
#          ('que', 'não', 'admira', ','): 1,
#          ('não', 'admira', ',', 'nem'): 1,
#          ('admira', ',', 'nem', 'provavelmente'): 1,
#          (',', 'nem', 'provavelmente', 'consternará'): 1,
#          ('nem', 'provavelmente', 'consternará', 'é'): 1,
#          ('provavelmente', 'consternará', 'é', 'se'): 1,
#          ('consternará', 'é', 'se', 'este'): 1,
#          ('é', 'se', 'este', 'outro'): 1,
#          ('se', 'este', 'outro', 'livro'): 1,
#          ('este', 'outro', 'livro', 'não'): 1,
#          ('outro', 'livro', 'não', 'tiver'): 1,
#          ('livro', 'não', 'tiver', 'os'): 1,
#          ('não', 'tiver', 'os', 'cem'): 1,
#          ('tiver', 'os', 'cem', 'leitores'): 1,
#          ('os', 'cem', 'leitores', 'de'): 1,
#          ('cem', 'leitores', 'de', 'Stendhal'): 1,
#          ('leitores', 'de', 'Stendhal', ','): 1,
#          ('de', 'Stendhal', ',', 'nem'): 1,
#          ('Stendhal', ',', 'nem', 'cinqüenta'): 1,
#          (',', 'nem', 'cinqüenta', ','): 1,
#          ('nem', 'cinqüenta', ',', 'nem'): 1,
#          ('cinqüenta', ',', 'nem', 'vinte'): 1,
#          (',', 'nem', 'vinte', 'e'): 1,
#          ('nem', 'vinte', 'e', ','): 1,
#          ('vinte', 'e', ',', 'quando'): 1,
#          ('e', ',', 'quando', 'muito'): 1,
#          (',', 'quando', 'muito', ','): 2,
#          ('quando', 'muito', ',', 'dez'): 1,
#          ('muito', ',', 'dez', '.'): 1,
#          (',', 'dez', '.', '</s>'): 1,
#          ('dez', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Dez'): 1,
#          ('<s>', '<s>', 'Dez', '?'): 1,
#          ('<s>', 'Dez', '?', '</s>'): 1,
#          ('Dez', '?', '</s>', '<s>'): 1,
#          ('?', '</s>', '<s>', '<s>'): 262,
#          ('<s>', '<s>', '<s>', 'Talvez'): 30,
#          ('<s>', '<s>', 'Talvez', 'cinco'): 2,
#          ('<s>', 'Talvez', 'cinco', '.'): 1,
#          ('Talvez', 'cinco', '.', '</s>'): 1,
#          ('cinco', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Trata'): 3,
#          ('<s>', '<s>', 'Trata', '-'): 2,
#          ('<s>', 'Trata', '-', 'se'): 1,
#          ('Trata', '-', 'se', ','): 1,
#          ('-', 'se', ',', 'na'): 1,
#          ('se', ',', 'na', 'verdade'): 1,
#          (',', 'na', 'verdade', ','): 4,
#          ('na', 'verdade', ',', 'de'): 1,
#          ('verdade', ',', 'de', 'uma'): 1,
#          (',', 'de', 'uma', 'obra'): 1,
#          ('de', 'um', 'Sterne', ','): 1,
#          ('um', 'Sterne', ',', 'ou'): 1,
#          ('Sterne', ',', 'ou', 'de'): 1,
#          (',', 'ou', 'de', 'um'): 1,
#          ('rabugens', 'de', 'pessimismo', '.'): 1,
#          ('de', 'pessimismo', '.', '</s>'): 1,
#          ('pessimismo', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Pode'): 1,
#          ('<s>', '<s>', 'Pode', 'ser'): 1,
#          ('<s>', 'Pode', 'ser', '.'): 1,
#          ('Pode', 'ser', '.', '</s>'): 2,
#          ('ser', '.', '</s>', '<s>'): 4,
#          ('<s>', '<s>', '<s>', 'Obra'): 1,
#          ('<s>', '<s>', 'Obra', 'de'): 1,
#          ('<s>', 'Obra', 'de', 'finado'): 1,
#          ('Obra', 'de', 'finado', '.'): 1,
#          ('de', 'finado', '.', '</s>'): 1,
#          ('finado', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Escrevi'): 2,
#          ('<s>', '<s>', 'Escrevi', '-'): 1,
#          ('<s>', 'Escrevi', '-', 'a'): 1,
#          ('Escrevi', '-', 'a', 'com'): 1,
#          ('-', 'a', 'com', 'a'): 2,
#          ('a', 'com', 'a', 'pena'): 1,
#          ('com', 'a', 'pena', 'da'): 1,
#          ('a', 'pena', 'da', 'galhofa'): 1,
#          ('pena', 'da', 'galhofa', 'e'): 1,
#          ('da', 'galhofa', 'e', 'a'): 1,
#          ('galhofa', 'e', 'a', 'tinta'): 1,
#          ('e', 'a', 'tinta', 'da'): 1,
#          ('a', 'tinta', 'da', 'melancolia'): 1,
#          ('tinta', 'da', 'melancolia', ','): 1,
#          ('da', 'melancolia', ',', 'e'): 1,
#          ('melancolia', ',', 'e', 'não'): 1,
#          (',', 'e', 'não', 'é'): 5,
#          ('e', 'não', 'é', 'difícil'): 1,
#          ('não', 'é', 'difícil', 'antever'): 1,
#          ('é', 'difícil', 'antever', 'o'): 1,
#          ('difícil', 'antever', 'o', 'que'): 1,
#          ('antever', 'o', 'que', 'poderá'): 1,
#          ('o', 'que', 'poderá', 'sair'): 1,
#          ('que', 'poderá', 'sair', 'desse'): 1,
#          ('poderá', 'sair', 'desse', 'conúbio'): 1,
#          ('sair', 'desse', 'conúbio', '.'): 1,
#          ('desse', 'conúbio', '.', '</s>'): 1,
#          ('conúbio', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Acresce'): 3,
#          ('<s>', '<s>', 'Acresce', 'que'): 3,
#          ('<s>', 'Acresce', 'que', 'a'): 1,
#          ('Acresce', 'que', 'a', 'gente'): 1,
#          ('que', 'a', 'gente', 'grave'): 1,
#          ('a', 'gente', 'grave', 'achará'): 1,
#          ('gente', 'grave', 'achará', 'no'): 1,
#          ('grave', 'achará', 'no', 'livro'): 1,
#          ('achará', 'no', 'livro', 'umas'): 1,
#          ('no', 'livro', 'umas', 'aparências'): 1,
#          ('livro', 'umas', 'aparências', 'de'): 1,
#          ('umas', 'aparências', 'de', 'puro'): 1,
#          ('aparências', 'de', 'puro', 'romance'): 1,
#          ('de', 'puro', 'romance', ','): 1,
#          ('puro', 'romance', ',', 'ao'): 1,
#          ('romance', ',', 'ao', 'passo'): 1,
#          (',', 'ao', 'passo', 'que'): 8,
#          ('ao', 'passo', 'que', 'a'): 3,
#          ('passo', 'que', 'a', 'gente'): 1,
#          ('que', 'a', 'gente', 'frívola'): 1,
#          ('a', 'gente', 'frívola', 'não'): 1,
#          ('gente', 'frívola', 'não', 'achará'): 1,
#          ('frívola', 'não', 'achará', 'nele'): 1,
#          ('não', 'achará', 'nele', 'o'): 1,
#          ('achará', 'nele', 'o', 'seu'): 1,
#          ('nele', 'o', 'seu', 'romance'): 1,
#          ('o', 'seu', 'romance', 'usual'): 1,
#          ('seu', 'romance', 'usual', ';'): 1,
#          ('romance', 'usual', ';', 'ei'): 1,
#          ('usual', ';', 'ei', '-'): 1,
#          (';', 'ei', '-', 'lo'): 2,
#          ('ei', '-', 'lo', 'aí'): 1,
#          ('-', 'lo', 'aí', 'fica'): 1,
#          ('lo', 'aí', 'fica', 'privado'): 1,
#          ('aí', 'fica', 'privado', 'da'): 1,
#          ('fica', 'privado', 'da', 'estima'): 1,
#          ('privado', 'da', 'estima', 'dos'): 1,
#          ('da', 'estima', 'dos', 'graves'): 1,
#          ('estima', 'dos', 'graves', 'e'): 1,
#          ('dos', 'graves', 'e', 'do'): 1,
#          ('graves', 'e', 'do', 'amor'): 1,
#          ('e', 'do', 'amor', 'dos'): 1,
#          ('do', 'amor', 'dos', 'frívolos'): 1,
#          ('amor', 'dos', 'frívolos', ','): 1,
#          ('dos', 'frívolos', ',', 'que'): 1,
#          ('frívolos', ',', 'que', 'são'): 1,
#          (',', 'que', 'são', 'as'): 1,
#          ('que', 'são', 'as', 'duas'): 1,
#          ('são', 'as', 'duas', 'colunas'): 1,
#          ('as', 'duas', 'colunas', 'máximas'): 1,
#          ('duas', 'colunas', 'máximas', 'da'): 1,
#          ('colunas', 'máximas', 'da', 'opinião'): 1,
#          ('máximas', 'da', 'opinião', '.'): 1,
#          ('da', 'opinião', '.', '</s>'): 2,
#          ('opinião', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Mas'): 68,
#          ('<s>', '<s>', 'Mas', 'eu'): 10,
#          ('<s>', 'Mas', 'eu', 'ainda'): 1,
#          ('Mas', 'eu', 'ainda', 'espero'): 1,
#          ('eu', 'ainda', 'espero', 'angariar'): 1,
#          ('ainda', 'espero', 'angariar', 'as'): 1,
#          ('espero', 'angariar', 'as', 'simpatias'): 1,
#          ('angariar', 'as', 'simpatias', 'da'): 1,
#          ('as', 'simpatias', 'da', 'opinião'): 1,
#          ('simpatias', 'da', 'opinião', ','): 1,
#          ('da', 'opinião', ',', 'e'): 1,
#          ('opinião', ',', 'e', 'o'): 1,
#          (',', 'e', 'o', 'primeiro'): 1,
#          ('e', 'o', 'primeiro', 'remédio'): 1,
#          ('o', 'primeiro', 'remédio', 'é'): 1,
#          ('primeiro', 'remédio', 'é', 'fugir'): 1,
#          ('remédio', 'é', 'fugir', 'a'): 1,
#          ('é', 'fugir', 'a', 'um'): 1,
#          ('fugir', 'a', 'um', 'prólogo'): 1,
#          ('a', 'um', 'prólogo', 'explícito'): 1,
#          ('um', 'prólogo', 'explícito', 'e'): 1,
#          ('prólogo', 'explícito', 'e', 'longo'): 1,
#          ('explícito', 'e', 'longo', '.'): 1,
#          ('e', 'longo', '.', '</s>'): 2,
#          ('longo', '.', '</s>', '<s>'): 3,
#          ('<s>', '<s>', 'O', 'melhor'): 4,
#          ('<s>', 'O', 'melhor', 'prólogo'): 1,
#          ('O', 'melhor', 'prólogo', 'é'): 1,
#          ('melhor', 'prólogo', 'é', 'o'): 1,
#          ('prólogo', 'é', 'o', 'que'): 1,
#          ('é', 'o', 'que', 'contém'): 1,
#          ('o', 'que', 'contém', 'menos'): 1,
#          ('que', 'contém', 'menos', 'coisas'): 1,
#          ('contém', 'menos', 'coisas', ','): 1,
#          ('menos', 'coisas', ',', 'ou'): 1,
#          ('coisas', ',', 'ou', 'o'): 1,
#          (',', 'ou', 'o', 'que'): 2,
#          ('ou', 'o', 'que', 'as'): 1,
#          ('o', 'que', 'as', 'diz'): 1,
#          ('que', 'as', 'diz', 'de'): 1,
#          ('as', 'diz', 'de', 'um'): 1,
#          ('diz', 'de', 'um', 'jeito'): 1,
#          ('de', 'um', 'jeito', 'obscuro'): 1,
#          ('um', 'jeito', 'obscuro', 'e'): 1,
#          ('jeito', 'obscuro', 'e', 'truncado'): 1,
#          ('obscuro', 'e', 'truncado', '.'): 1,
#          ('e', 'truncado', '.', '</s>'): 1,
#          ('truncado', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Conseguintemente'): 1,
#          ('<s>', '<s>', 'Conseguintemente', ','): 1,
#          ('<s>', 'Conseguintemente', ',', 'evito'): 1,
#          ('Conseguintemente', ',', 'evito', 'contar'): 1,
#          (',', 'evito', 'contar', 'o'): 1,
#          ('evito', 'contar', 'o', 'processo'): 1,
#          ('contar', 'o', 'processo', 'extraordinário'): 1,
#          ('o', 'processo', 'extraordinário', 'que'): 1,
#          ('processo', 'extraordinário', 'que', 'empreguei'): 1,
#          ('extraordinário', 'que', 'empreguei', 'na'): 1,
#          ('que', 'empreguei', 'na', 'composição'): 1,
#          ('empreguei', 'na', 'composição', 'destas'): 1,
#          ('na', 'composição', 'destas', 'Memórias'): 1,
#          ('composição', 'destas', 'Memórias', ','): 1,
#          ('destas', 'Memórias', ',', 'trabalhadas'): 1,
#          ('Memórias', ',', 'trabalhadas', 'cá'): 1,
#          (',', 'trabalhadas', 'cá', 'no'): 1,
#          ('trabalhadas', 'cá', 'no', 'outro'): 1,
#          ('cá', 'no', 'outro', 'mundo'): 1,
#          ('no', 'outro', 'mundo', '.'): 1,
#          ('outro', 'mundo', '.', '</s>'): 1,
#          ('mundo', '.', '</s>', '<s>'): 3,
#          ('<s>', '<s>', '<s>', 'Seria'): 3,
#          ('<s>', '<s>', 'Seria', 'curioso'): 1,
#          ('<s>', 'Seria', 'curioso', ','): 1,
#          ('Seria', 'curioso', ',', 'mas'): 1,
#          ('curioso', ',', 'mas', 'nimiamente'): 1,
#          (',', 'mas', 'nimiamente', 'extenso'): 1,
#          ('mas', 'nimiamente', 'extenso', ','): 1,
#          ('nimiamente', 'extenso', ',', 'e'): 1,
#          ('extenso', ',', 'e', 'aliás'): 1,
#          (',', 'e', 'aliás', 'desnecessário'): 1,
#          ('e', 'aliás', 'desnecessário', 'ao'): 1,
#          ('aliás', 'desnecessário', 'ao', 'entendimento'): 1,
#          ('desnecessário', 'ao', 'entendimento', 'da'): 1,
#          ('ao', 'entendimento', 'da', 'obra'): 1,
#          ('entendimento', 'da', 'obra', '.'): 1,
#          ('da', 'obra', '.', '</s>'): 1,
#          ('obra', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', 'A', 'obra'): 1,
#          ('<s>', 'A', 'obra', 'em'): 1,
#          ('A', 'obra', 'em', 'si'): 1,
#          ('obra', 'em', 'si', 'mesma'): 1,
#          ('em', 'si', 'mesma', 'é'): 1,
#          ('si', 'mesma', 'é', 'tudo'): 1,
#          ('mesma', 'é', 'tudo', ':'): 1,
#          ('é', 'tudo', ':', 'se'): 1,
#          ('tudo', ':', 'se', 'te'): 1,
#          (':', 'se', 'te', 'agradar'): 1,
#          ('se', 'te', 'agradar', ','): 1,
#          ('te', 'agradar', ',', 'fino'): 1,
#          ('agradar', ',', 'fino', 'leitor'): 1,
#          (',', 'fino', 'leitor', ','): 1,
#          ('fino', 'leitor', ',', 'pago'): 1,
#          ('leitor', ',', 'pago', '-'): 1,
#          (',', 'pago', '-', 'me'): 1,
#          ('pago', '-', 'me', 'da'): 1,
#          ('-', 'me', 'da', 'tarefa'): 1,
#          ('me', 'da', 'tarefa', ';'): 1,
#          ('da', 'tarefa', ';', 'se'): 1,
#          ('tarefa', ';', 'se', 'te'): 1,
#          (';', 'se', 'te', 'não'): 1,
#          ('se', 'te', 'não', 'agradar'): 1,
#          ('te', 'não', 'agradar', ','): 1,
#          ('não', 'agradar', ',', 'pago'): 1,
#          ('agradar', ',', 'pago', '-'): 1,
#          (',', 'pago', '-', 'te'): 1,
#          ('pago', '-', 'te', 'com'): 1,
#          ('-', 'te', 'com', 'um'): 1,
#          ('te', 'com', 'um', 'piparote'): 1,
#          ('com', 'um', 'piparote', ','): 1,
#          ('um', 'piparote', ',', 'e'): 1,
#          ('piparote', ',', 'e', 'adeus'): 1,
#          (',', 'e', 'adeus', '.'): 1,
#          ('e', 'adeus', '.', '</s>'): 1,
#          ('adeus', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Brás'): 1,
#          ('<s>', '<s>', 'Brás', 'Cubas'): 1,
#          ('<s>', 'Brás', 'Cubas', '.'): 1,
#          ('Brás', 'Cubas', '.', '</s>'): 6,
#          ('Cubas', '.', '</s>', '<s>'): 8,
#          ('<s>', '<s>', '<s>', 'CAPÍTULO'): 160,
#          ('<s>', '<s>', 'CAPÍTULO', 'PRIMEIRO'): 1,
#          ('<s>', 'CAPÍTULO', 'PRIMEIRO', '/'): 1,
#          ('CAPÍTULO', 'PRIMEIRO', '/', 'ÓBITO'): 1,
#          ('PRIMEIRO', '/', 'ÓBITO', 'DO'): 1,
#          ('/', 'ÓBITO', 'DO', 'AUTOR'): 1,
#          ('ÓBITO', 'DO', 'AUTOR', '</s>'): 1,
#          ('DO', 'AUTOR', '</s>', '<s>'): 1,
#          ('AUTOR', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Algum'): 3,
#          ('<s>', '<s>', 'Algum', 'tempo'): 2,
#          ('<s>', 'Algum', 'tempo', 'hesitei'): 1,
#          ('Algum', 'tempo', 'hesitei', 'se'): 1,
#          ('tempo', 'hesitei', 'se', 'devia'): 1,
#          ('hesitei', 'se', 'devia', 'abrir'): 1,
#          ('se', 'devia', 'abrir', 'estas'): 1,
#          ('devia', 'abrir', 'estas', 'memórias'): 1,
#          ('abrir', 'estas', 'memórias', 'pelo'): 1,
#          ('estas', 'memórias', 'pelo', 'princípio'): 1,
#          ('memórias', 'pelo', 'princípio', 'ou'): 1,
#          ('pelo', 'princípio', 'ou', 'pelo'): 1,
#          ('princípio', 'ou', 'pelo', 'fim'): 1,
#          ('ou', 'pelo', 'fim', ','): 1,
#          ('pelo', 'fim', ',', 'isto'): 1,
#          ('fim', ',', 'isto', 'é'): 1,
#          (',', 'isto', 'é', ','): 7,
#          ('isto', 'é', ',', 'se'): 1,
#          ('é', ',', 'se', 'poria'): 1,
#          (',', 'se', 'poria', 'em'): 1,
#          ('se', 'poria', 'em', 'primeiro'): 1,
#          ('poria', 'em', 'primeiro', 'lugar'): 1,
#          ('em', 'primeiro', 'lugar', 'o'): 1,
#          ('primeiro', 'lugar', 'o', 'meu'): 1,
#          ('lugar', 'o', 'meu', 'nascimento'): 1,
#          ('o', 'meu', 'nascimento', 'ou'): 1,
#          ('meu', 'nascimento', 'ou', 'a'): 1,
#          ('nascimento', 'ou', 'a', 'minha'): 1,
#          ('ou', 'a', 'minha', 'morte'): 1,
#          ('a', 'minha', 'morte', '.'): 1,
#          ('minha', 'morte', '.', '</s>'): 1,
#          ('morte', '.', '</s>', '<s>'): 8,
#          ('<s>', '<s>', '<s>', 'Suposto'): 1,
#          ('<s>', '<s>', 'Suposto', 'o'): 1,
#          ('<s>', 'Suposto', 'o', 'uso'): 1,
#          ('Suposto', 'o', 'uso', 'vulgar'): 1,
#          ('o', 'uso', 'vulgar', 'seja'): 1,
#          ('uso', 'vulgar', 'seja', 'começar'): 1,
#          ('vulgar', 'seja', 'começar', 'pelo'): 1,
#          ('seja', 'começar', 'pelo', 'nascimento'): 1,
#          ('começar', 'pelo', 'nascimento', ','): 1,
#          ('pelo', 'nascimento', ',', 'duas'): 1,
#          ('nascimento', ',', 'duas', 'considerações'): 1,
#          (',', 'duas', 'considerações', 'me'): 1,
#          ('duas', 'considerações', 'me', 'levaram'): 1,
#          ('considerações', 'me', 'levaram', 'a'): 1,
#          ('me', 'levaram', 'a', 'adotar'): 1,
#          ('levaram', 'a', 'adotar', 'diferente'): 1,
#          ('a', 'adotar', 'diferente', 'método'): 1,
#          ('adotar', 'diferente', 'método', ':'): 1,
#          ('diferente', 'método', ':', 'a'): 1,
#          ('método', ':', 'a', 'primeira'): 1,
#          (':', 'a', 'primeira', 'é'): 1,
#          ('a', 'primeira', 'é', 'que'): 1,
#          ('primeira', 'é', 'que', 'eu'): 1,
#          ('é', 'que', 'eu', 'não'): 2,
#          ('que', 'eu', 'não', 'sou'): 2,
#          ('eu', 'não', 'sou', 'propriamente'): 1,
#          ('não', 'sou', 'propriamente', 'um'): 1,
#          ('sou', 'propriamente', 'um', 'autor'): 1,
#          ('propriamente', 'um', 'autor', 'defunto'): 1,
#          ('um', 'autor', 'defunto', ','): 1,
#          ('autor', 'defunto', ',', 'mas'): 1,
#          ('defunto', ',', 'mas', 'um'): 1,
#          (',', 'mas', 'um', 'defunto'): 1,
#          ('mas', 'um', 'defunto', 'autor'): 1,
#          ('um', 'defunto', 'autor', ','): 1,
#          ('defunto', 'autor', ',', 'para'): 1,
#          ('autor', ',', 'para', 'quem'): 1,
#          (',', 'para', 'quem', 'a'): 1,
#          ('para', 'quem', 'a', 'campa'): 1,
#          ('quem', 'a', 'campa', 'foi'): 1,
#          ('a', 'campa', 'foi', 'outro'): 1,
#          ('campa', 'foi', 'outro', 'berço'): 1,
#          ('foi', 'outro', 'berço', ';'): 1,
#          ('outro', 'berço', ';', 'a'): 1,
#          ('berço', ';', 'a', 'segunda'): 1,
#          (';', 'a', 'segunda', 'é'): 1,
#          ('a', 'segunda', 'é', 'que'): 1,
#          ('segunda', 'é', 'que', 'o'): 1,
#          ('é', 'que', 'o', 'escrito'): 1,
#          ('que', 'o', 'escrito', 'ficaria'): 1,
#          ('o', 'escrito', 'ficaria', 'assim'): 1,
#          ('escrito', 'ficaria', 'assim', 'mais'): 1,
#          ('ficaria', 'assim', 'mais', 'galante'): 1,
#          ('assim', 'mais', 'galante', 'e'): 1,
#          ('mais', 'galante', 'e', 'mais'): 1,
#          ('galante', 'e', 'mais', 'novo'): 1,
#          ('e', 'mais', 'novo', '.'): 1,
#          ('mais', 'novo', '.', '</s>'): 1,
#          ('novo', '.', '</s>', '<s>'): 3,
#          ('<s>', '<s>', '<s>', 'Moisés'): 1,
#          ('<s>', '<s>', 'Moisés', ','): 1,
#          ('<s>', 'Moisés', ',', 'que'): 1,
#          ('Moisés', ',', 'que', 'também'): 1,
#          (',', 'que', 'também', 'contou'): 1,
#          ('que', 'também', 'contou', 'a'): 1,
#          ('também', 'contou', 'a', 'sua'): 1,
#          ('contou', 'a', 'sua', 'morte'): 1,
#          ('a', 'sua', 'morte', ','): 1,
#          ('sua', 'morte', ',', 'não'): 1,
#          ('morte', ',', 'não', 'a'): 1,
#          (',', 'não', 'a', 'pôs'): 1,
#          ('não', 'a', 'pôs', 'no'): 1,
#          ('a', 'pôs', 'no', 'intróito'): 1,
#          ('pôs', 'no', 'intróito', ','): 1,
#          ('no', 'intróito', ',', 'mas'): 1,
#          ('intróito', ',', 'mas', 'no'): 1,
#          (',', 'mas', 'no', 'cabo'): 1,
#          ('mas', 'no', 'cabo', ':'): 1,
#          ('no', 'cabo', ':', 'diferença'): 1,
#          ('cabo', ':', 'diferença', 'radical'): 1,
#          (':', 'diferença', 'radical', 'entre'): 1,
#          ('diferença', 'radical', 'entre', 'este'): 1,
#          ('radical', 'entre', 'este', 'livro'): 1,
#          ('entre', 'este', 'livro', 'e'): 1,
#          ('este', 'livro', 'e', 'o'): 2,
#          ('livro', 'e', 'o', 'Pentateuco'): 1,
#          ('e', 'o', 'Pentateuco', '.'): 1,
#          ('o', 'Pentateuco', '.', '</s>'): 1,
#          ('Pentateuco', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Dito'): 3,
#          ('<s>', '<s>', 'Dito', 'isto'): 2,
#          ('<s>', 'Dito', 'isto', ','): 2,
#          ('Dito', 'isto', ',', 'expirei'): 1,
#          ('isto', ',', 'expirei', 'às'): 1,
#          (',', 'expirei', 'às', 'duas'): 1,
#          ('expirei', 'às', 'duas', 'horas'): 1,
#          ('às', 'duas', 'horas', 'da'): 1,
#          ('duas', 'horas', 'da', 'tarde'): 2,
#          ('horas', 'da', 'tarde', 'de'): 1,
#          ('da', 'tarde', 'de', 'uma'): 1,
#          ('tarde', 'de', 'uma', 'sexta'): 1,
#          ('de', 'uma', 'sexta', '-'): 1,
#          ('uma', 'sexta', '-', 'feira'): 1,
#          ('sexta', '-', 'feira', 'do'): 1,
#          ('-', 'feira', 'do', 'mês'): 1,
#          ('feira', 'do', 'mês', 'de'): 1,
#          ('do', 'mês', 'de', 'agosto'): 1,
#          ('mês', 'de', 'agosto', 'de'): 1,
#          ('de', 'agosto', 'de', '1869'): 1,
#          ('agosto', 'de', '1869', ','): 1,
#          ('de', '1869', ',', 'na'): 1,
#          ('1869', ',', 'na', 'minha'): 1,
#          (',', 'na', 'minha', 'bela'): 1,
#          ('na', 'minha', 'bela', 'chácara'): 1,
#          ('minha', 'bela', 'chácara', 'de'): 1,
#          ('bela', 'chácara', 'de', 'Catumbi'): 1,
#          ('chácara', 'de', 'Catumbi', '.'): 1,
#          ('de', 'Catumbi', '.', '</s>'): 1,
#          ('Catumbi', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Tinha'): 18,
#          ('<s>', '<s>', 'Tinha', 'uns'): 1,
#          ('<s>', 'Tinha', 'uns', 'sessenta'): 1,
#          ('Tinha', 'uns', 'sessenta', 'e'): 1,
#          ('uns', 'sessenta', 'e', 'quatro'): 1,
#          ('sessenta', 'e', 'quatro', 'anos'): 2,
#          ('e', 'quatro', 'anos', ','): 2,
#          ('quatro', 'anos', ',', 'rijos'): 1,
#          ('anos', ',', 'rijos', 'e'): 1,
#          (',', 'rijos', 'e', 'prósperos'): 1,
#          ('rijos', 'e', 'prósperos', ','): 1,
#          ('e', 'prósperos', ',', 'era'): 1,
#          ('prósperos', ',', 'era', 'solteiro'): 1,
#          (',', 'era', 'solteiro', ','): 1,
#          ('era', 'solteiro', ',', 'possuía'): 1,
#          ('solteiro', ',', 'possuía', 'cerca'): 1,
#          (',', 'possuía', 'cerca', 'de'): 1,
#          ('possuía', 'cerca', 'de', 'trezentos'): 1,
#          ('cerca', 'de', 'trezentos', 'contos'): 1,
#          ('de', 'trezentos', 'contos', 'e'): 1,
#          ('trezentos', 'contos', 'e', 'fui'): 1,
#          ('contos', 'e', 'fui', 'acompanhado'): 1,
#          ('e', 'fui', 'acompanhado', 'ao'): 1,
#          ('fui', 'acompanhado', 'ao', 'cemitério'): 1,
#          ('acompanhado', 'ao', 'cemitério', 'por'): 1,
#          ('ao', 'cemitério', 'por', 'onze'): 1,
#          ('cemitério', 'por', 'onze', 'amigos'): 1,
#          ('por', 'onze', 'amigos', '.'): 1,
#          ('onze', 'amigos', '.', '</s>'): 1,
#          ('amigos', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Onze'): 1,
#          ('<s>', '<s>', 'Onze', 'amigos'): 1,
#          ('<s>', 'Onze', 'amigos', '!'): 1,
#          ('Onze', 'amigos', '!', '</s>'): 1,
#          ('amigos', '!', '</s>', '<s>'): 2,
#          ('!', '</s>', '<s>', '<s>'): 295,
#          ('<s>', '<s>', '<s>', 'Verdade'): 5,
#          ('<s>', '<s>', 'Verdade', 'é'): 5,
#          ('<s>', 'Verdade', 'é', 'que'): 5,
#          ('Verdade', 'é', 'que', 'não'): 1,
#          ('é', 'que', 'não', 'houve'): 1,
#          ('que', 'não', 'houve', 'cartas'): 1,
#          ('não', 'houve', 'cartas', 'nem'): 1,
#          ('houve', 'cartas', 'nem', 'anúncios'): 1,
#          ('cartas', 'nem', 'anúncios', '.'): 1,
#          ('nem', 'anúncios', '.', '</s>'): 1,
#          ('anúncios', '.', '</s>', '<s>'): 1,
#          ('<s>', 'Acresce', 'que', 'chovia'): 1,
#          ('Acresce', 'que', 'chovia', '\x97'): 1,
#          ('que', 'chovia', '\x97', 'peneirava'): 1,
#          ('chovia', '\x97', 'peneirava', 'uma'): 1,
#          ('\x97', 'peneirava', 'uma', 'chuvinha'): 1,
#          ('peneirava', 'uma', 'chuvinha', 'miúda'): 1,
#          ('uma', 'chuvinha', 'miúda', ','): 1,
#          ('chuvinha', 'miúda', ',', 'triste'): 1,
#          ('miúda', ',', 'triste', 'e'): 1,
#          (',', 'triste', 'e', 'constante'): 1,
#          ('triste', 'e', 'constante', ','): 1,
#          ('e', 'constante', ',', 'tão'): 1,
#          ('constante', ',', 'tão', 'constante'): 1,
#          (',', 'tão', 'constante', 'e'): 1,
#          ('tão', 'constante', 'e', 'tão'): 1,
#          ('constante', 'e', 'tão', 'triste'): 1,
#          ('e', 'tão', 'triste', ','): 2,
#          ('tão', 'triste', ',', 'que'): 2,
#          ('triste', ',', 'que', 'levou'): 1,
#          (',', 'que', 'levou', 'um'): 1,
#          ('que', 'levou', 'um', 'daqueles'): 1,
#          ('levou', 'um', 'daqueles', 'fiéis'): 1,
#          ('um', 'daqueles', 'fiéis', 'da'): 1,
#          ...})

# %%
fourgram_key = list(count_fourgram.keys())
fivegram_key = list(count_fivegram.keys())

# %%
type(fourgram_key)
# Out:
# list

# %%
len(count_fourgram)
# Out:
# 76676

# %%
len(count_fivegram)
# Out:
# 81719

# %% [markdown]
# Calcular a probabilidade

# %%
list_fourgram = []
list_lastwordfour = []
list_probsfour = []

for t in fivegram_key:
    key_fourgram = (t[0], t[1],t[2], t[3])
    prob = count_fivegram[t] / count_fourgram[key_fourgram]
    list_fourgram.append(key_fourgram)
    list_lastwordfour.append(t[4])
    list_probsfour.append(prob)

# %%
model_df2 = pd.DataFrame({'fourgram': list_fourgram, 'lastword': list_lastwordfour, 'prob': list_probsfour})
model_df2[0:2]
# Out:
#                    fourgram lastword      prob
# 0      (<s>, <s>, <s>, <s>)  Romance  0.000262
# 1  (<s>, <s>, <s>, Romance)        ,  1.000000

# %%
fourgram_df = model_df2.loc[model_df2['fourgram'] == ('Romance', ',', 'Memórias', 'Póstumas')]
fourgram_df
# Out:
#                            fourgram lastword  prob
# 4  (Romance, ,, Memórias, Póstumas)       de   1.0

# %%
calc_probfour = sum(fourgram_df['prob'])
calc_probfour
# Out:
# 1.0

# %% [raw]
# Criando o modelo

# %%
num_sents = 50
current_fourgram = ('<s>', '<s>', '<s>', '<s>')
i = 0
while i < num_sents:
    df2 = model_df2.loc[model_df2['fourgram'] == current_fourgram]
    words = df2['lastword'].values
    probs = df2['prob'].values
    last_word = random.choices(words, probs)[0]
    
    current_fourgram = (current_fourgram[1], current_fourgram[2],current_fourgram[3], last_word)
    
    if last_word == '</s>':
        i+=1
    
    if last_word != '<s>' and last_word != '</s>':
        print(last_word, end=' ')
# Out:
#  Você é das Arábias , dizia - me a mucama . Assim , este frango , que eu almocei agora mesmo , é o resultado de uma multidão de esforços e lutas , executados com o único fim de acudir à paixão do lucro , que era o seu ofício , remexendo a alma e a vida dos outros .  Meu senhor ! A história do homem e da Terra tinha assim uma intensidade que lhe não podiam dar nem a imaginação nem a ciência , porque a ciência é mais lenta e a imaginação mais vaga , enquanto que o que eu ali via era a condensação viva de todos os tempos . Entretanto , ele suportava com firmeza o meu espanto .  Onde estamos ? Pudera não ! Havia ainda o primo de Virgília , o Luís Dutra , que eu agora desarmava à força de lhe falar nos versos e prosas , e de o apresentar aos conhecidos . Corro ; era minha irmã Sabina .  Virgília ? Agora até daqui a ... Quanto à censura de ingratidão , Quincas Borba rejeitou - a inteiramente , não como improvável , mas como absurda , por não obedecer às conclusões de uma boa filosofia humanística . Ela estremeceu , colheu - me a cabeça entre as palmas , fitou - me os olhos , depois afagou - me com um gesto maternal ... Enquanto eu fazia comigo mesmo aquela reflexão , entrou na loja um sujeito baixo , sem chapéu , trazendo pela mão uma menina de quatro anos . Insinuei que deveria ser muitíssimo longe ; mas o hipopótamo não me entendeu ou não me ouviu , se é que não fingiu uma dessas coisas ; e , perguntando - lhe , visto que ele falava , se era descendente do cavalo de Aquiles ou da asna de Balaão , retorquiu - me com um gesto maternal ... Prólogo da terceira edição Virgília amava - me com fúria ; aquela resposta era a verdade patente . D . Eusébia levou o lenço aos olhos . O espírito , como um pássaro , não se lhe deu da corrente dos anos , arrepiou o vôo na direção da fonte original , e foi beber da água fresca e pura , ainda não mesclada do enxurro da vida . Abaixei - me ; era uma moeda de ouro , uma meia dobra . Compelle intrare , como dizia Jesus . CAPÍTULO XXX / A FLOR DA MOITA Eu fiquei como há de estar o leitor ,  um pouco jactanciosa , é certo , mas foi o mesmo que nada .  De marujo poeta . exclamou Sabina . A razão é que , ao lado dessas faltas , coube - me a boa fortuna de não comprar o pão com o suor do meu rosto . Tratou - me ontem como se me tivesse ódio .  Não é conveniente , dá muito na vista ... E repito : não é meu . A proposta , porém , desdizia tanto das minhas sensações últimas , que eu cheguei a perguntar - lhe se deveras me não achava doido . Como tocássemos , casualmente , nuns amores ilegítimos , meio secretos , meio divulgados , vi - a falar com desdém e um pouco de indignação da mulher de que se tratava , aliás sua amiga . Estava por pouco . Levantei - me , atirei o chapéu a uma cadeira , ou à cadeira , porque havia lá em casa a  cadeira do Viegas , obra especial , conchegada , feita para gente enferma ou anciã . Quincas Borba divergiu do alienista em relação ao meu criado . Erasmo , que no seu Elogio da Sandice escreveu algumas coisas boas , chamou a atenção para a complacência com que dois burros se coçam um ao outro . Eu não sabia nem pensava nada . Qual ! Havia alguma afetação naquele desdém ; era um arrebique do gesto . Cada estação da vida é uma edição , que corrige a anterior , e que será corrigida também , até a edição definitiva , que o editor dá de graça aos vermes . Parece - me que Sabina foi além , fazendo - lhe certas confidências , segundo me disse ; mas em todo caso ela não é tia carnal de Nhã - loló de um modo verdadeiramente impetuoso .  Vou . As bexigas tinham sido terríveis ; os sinais , grandes e muitos , faziam saliências e encarnas , declives e aclives , e davam uma sensação de lixa grossa , enormemente grossa . Redobrei de atenção ; fitei a vista ; ia enfim ver o último ,  o último ! Lobo Neves acompanhava - me com muita placidez e dignidade , e até com certa benevolência superior ; e tudo aquilo me irritava também , e me tornava mais amargo e longo o jantar . Virgília entr ...
